# %% [markdown]
# # EYES-DEFY-ANEMIA — K-fold re-training: Mid tier (4 of 12 combos)
#
# One of **3 tier-specific notebooks** (Base / Mid / Strong), covering the 12 combos that completed the original 18-combo Optuna sweep (the 6 Transformer-family combos OOM'd and are out of scope here). Each notebook re-trains its tier's combos using their own already-found best hyperparameters (no re-tuning) under **3-fold cross-validation** (`Segmentation/scripts/train_pretrained_kfold/kfold_engine.py`), so the reported test-set metric is a mean ± std across 3 independent trainings instead of one point estimate.
#
# **This notebook covers:**
# - ResNet101 DeepLabV3+ (CNN, ~45.7M), `palpebral`
# - ResNet101 DeepLabV3+ (CNN, ~45.7M), `forniceal_palpebral`
# - CoAtNet-2 U-Net (Hybrid, ~78.0M), `palpebral`
# - CoAtNet-2 U-Net (Hybrid, ~78.0M), `forniceal_palpebral`
#
# **Estimated time: ~3.4h worst-case (ResNet101+DeepLabV3+ ~1.4h + CoAtNet-2 ~2.0h)** — comfortably within one 12h Kaggle session.
#
# **Confirmed settings:** `BATCH_SIZE=32`, `MAX_EPOCHS=250`, `EARLY_STOPPING_PATIENCE=7`, `ReduceLROnPlateau` LR scheduler (factor=0.5, patience=3) — none of trainer_engine.py's original Optuna-sweep settings (30 epochs, patience 5, batch 16, no scheduler) apply here. Full rationale and design decisions: `Segmentation/.project_memory/05_kfold_reevaluation.md`.
#
# Run the 3 tier notebooks independently, in separate Kaggle sessions.

# %% [markdown]
# ## Setup

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# GPU: Tesla T4

# %%
# rm -rf first so a re-run within the same kernel session stays idempotent
# instead of nesting a second clone inside the first.
# !rm -rf eyes-defy-anemia
# !git clone https://github.com/manivafapour/eyes-defy-anemia.git
# %cd eyes-defy-anemia
# Out:
# Cloning into 'eyes-defy-anemia'...
# remote: Enumerating objects: 1699, done.
# remote: Counting objects: 100% (1380/1380), done.
# remote: Compressing objects: 100% (939/939), done.
# remote: Total 1699 (delta 568), reused 1206 (delta 427), pack-reused 319 (from 1)
# Receiving objects: 100% (1699/1699), 100.78 MiB | 37.04 MiB/s, done.
# Resolving deltas: 100% (731/731), done.
# /kaggle/working/eyes-defy-anemia

# %%
# Diagnostic, not a hardcoded assumption -- Kaggle's actual dataset mount
# path does not always match its display name, and can be nested deeper
# than expected (this project has been bitten by this before, twice now:
# see classification/.project_memory/kaggle/01_kaggle_notes.md -- real
# paths have landed under /kaggle/input/datasets/<username>/<slug>/, not
# directly under /kaggle/input/<slug>/). Recurses a few levels deep so
# this is caught in one pass instead of needing to descend manually.
# Read the output below, THEN set the dataset dir variable(s) in the next cell.
import os


def print_tree(path, depth=0, max_depth=4):
    for entry in sorted(os.listdir(path)):
        full = os.path.join(path, entry)
        print("  " * depth + entry)
        if os.path.isdir(full) and depth < max_depth:
            print_tree(full, depth + 1, max_depth)


print_tree("/kaggle/input")
# Out:
# datasets
#   manivafapour21
#     aligned-raw
#       aligned_raw
#         alignment_log.csv
#         images
#         masks
#     aligned-raw-forniceal
#       aligned_raw_forniceal
#         alignment_log.csv
#         images
#         masks

# %% [markdown]
# **Before running the next cell:** attach your uploaded dataset(s) to this notebook -- either both zips together as ONE Kaggle dataset, or as TWO SEPARATE datasets (this is what actually happened the first time this notebook was run: Kaggle listed them individually in the Input panel as `aligned_raw` and `aligned_raw_forniceal`). Either way, run the listing cell above, read its REAL printed output, and set the path(s) below from that -- **not** the placeholder text left in by default, and not a guessed path based on the dataset's display name (Kaggle's actual mount path does not always match it).

# %%
# Confirmed real mount paths (project author's Kaggle account, verified via
# the print_tree() listing above on 2026-08-08 -- see
# Segmentation/.project_memory/kaggle/01_kaggle_notes.md for the full
# doubly-nested structure this came from). If you re-attach the datasets
# under a different username/slug, or Kaggle changes its mount scheme again,
# re-run the listing cell above and update these two lines from its real
# output -- don't guess.
ALIGNED_RAW_DATASET_DIR = "/kaggle/input/datasets/manivafapour21/aligned-raw"
ALIGNED_RAW_FORNICEAL_DATASET_DIR = "/kaggle/input/datasets/manivafapour21/aligned-raw-forniceal"

# %%
# Only packages actually missing from Kaggle's base image (torch/torchvision,
# opencv, pandas, PIL, scikit-learn -- and therefore scipy AND sklearn's
# StratifiedKFold, its own dependency -- are already there; scipy is listed
# explicitly anyway rather than silently assumed, since it is a real,
# load-bearing dependency for HD95 in segmentation_metrics.py. No optuna
# here -- these notebooks re-train with FIXED hyperparameters (each combo's
# own best_params from the earlier Optuna sweep), not a fresh search.
# Deliberately NOT `pip install -r requirements.txt` -- that file is pinned
# to the local Windows/CUDA 13.0 build and would try to reinstall Kaggle's
# own correctly configured GPU PyTorch with an incompatible build.
# !pip install -q albumentations scipy segmentation-models-pytorch timm transformers einops
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 4.1 MB/s eta 0:00:00

# %% [markdown]
# ## Data

# %%
import shutil
import zipfile
from pathlib import Path

DST_ROOT = Path("Segmentation/data/processed")


def stage_tissue_data(name: str, dataset_dir: str):
    """Copies {name}/ from the given Kaggle-attached dataset directory into
    Segmentation/data/processed/{name}/. Tries three possible layouts rather
    than assuming one, since Kaggle can present an uploaded zip differently
    depending on upload method:
      1. dataset_dir/{name}/images,masks/  -- the zip's own internal "{name}/"
         prefix preserved as-is (this is how aligned_raw.zip/
         aligned_raw_forniceal.zip were actually built -- see
         Segmentation/scripts/build_aligned_dataset{,_forniceal}.py).
      2. dataset_dir/images,masks/         -- Kaggle stripped/flattened that
         top-level folder on extraction.
      3. dataset_dir/{name}.zip            -- never auto-extracted at all,
         still sitting there as a raw zip file.
    """
    dataset_dir = Path(dataset_dir)
    dst = DST_ROOT / name
    shutil.rmtree(dst, ignore_errors=True)

    nested_dir = dataset_dir / name
    flat_zip = dataset_dir / f"{name}.zip"

    if nested_dir.is_dir():
        shutil.copytree(nested_dir, dst)
    elif (dataset_dir / "images").is_dir() and (dataset_dir / "masks").is_dir():
        shutil.copytree(dataset_dir, dst)
    elif flat_zip.is_file():
        dst.mkdir(parents=True, exist_ok=True)
        with zipfile.ZipFile(flat_zip) as zf:
            zf.extractall(DST_ROOT)  # zip's own internal paths already start with f"{name}/"
    else:
        raise FileNotFoundError(
            f"Could not find {name}/, images+masks/, or {name}.zip under {dataset_dir} -- "
            f"run the /kaggle/input listing cell above and check what's actually there."
        )

    n_images = len(list((dst / "images").glob("*.jpg")))
    n_masks = len(list((dst / "masks").glob("*.png")))
    print(f"{name}: {n_images} images, {n_masks} masks staged at {dst}")


stage_tissue_data("aligned_raw", ALIGNED_RAW_DATASET_DIR)
stage_tissue_data("aligned_raw_forniceal", ALIGNED_RAW_FORNICEAL_DATASET_DIR)
# Out:
# aligned_raw: 201 images, 201 masks staged at Segmentation/data/processed/aligned_raw
# aligned_raw_forniceal: 211 images, 211 masks staged at Segmentation/data/processed/aligned_raw_forniceal

# %%
# Combined sanity check, run BEFORE any real training:
#   1. Confirm the pip-installed heavy dependencies actually work -- a
#      dataloader-only check would NOT catch a missing/broken install here
#      (classification's own Kaggle notes: a plain dataloader check only
#      exercises dataset.py's imports, so a missing package silently
#      surfaces only much later, on the first real training script).
#   2. Confirm the 9-model registry itself imports cleanly.
#   3. Pull one real batch from BOTH tissue-type dataloaders.
import sys
from pathlib import Path

sys.path.insert(0, str(Path("Segmentation/scripts").resolve()))
sys.path.insert(0, str(Path("Segmentation").resolve()))

import segmentation_models_pytorch as smp
import timm
import transformers
import einops

print("segmentation_models_pytorch", smp.__version__)
print("timm", timm.__version__)
print("transformers", transformers.__version__)
print("einops", einops.__version__)

from models.segmentation.pretrained_registry import ARCHITECTURE_REGISTRY
print(f"\n{len(ARCHITECTURE_REGISTRY)} architectures registered:")
for name in ARCHITECTURE_REGISTRY:
    print(" ", name)

from dataset import get_dataloaders

loaders = get_dataloaders()
for key in ["aligned_seg_train", "aligned_seg_forniceal_train"]:
    images, masks = next(iter(loaders[key]))
    print(f"\n{key}: image batch {tuple(images.shape)}, mask batch {tuple(masks.shape)}, "
          f"{len(loaders[key].dataset)} patients")
# Out:
# segmentation_models_pytorch 0.5.0
# timm 1.0.26
# transformers 5.0.0
# einops 0.8.2
#
# 9 architectures registered:
#   cnn_base_efficientnet_b1_unet
#   cnn_mid_resnet101_deeplabv3plus
#   cnn_strong_convnext_large_unet
#   hybrid_base_coatnet0_unet
#   hybrid_mid_coatnet2_unet
#   hybrid_strong_transunet
#   transformer_base_segformer_b2
#   transformer_mid_swin_base_upernet
#   transformer_strong_swin_large_upernet
#
# aligned_seg_train: image batch (16, 3, 256, 256), mask batch (16, 1, 256, 256), 143 patients
#
# aligned_seg_forniceal_train: image batch (16, 3, 256, 256), mask batch (16, 1, 256, 256), 147 patients

# %% [markdown]
# ## Training

# %%
import shutil
from pathlib import Path


def sync_outputs():
    """Consolidates Segmentation/outputs/{checkpoints,logs,plots}/ into a single
    top-level /kaggle/working/outputs/ folder and re-zips it to
    /kaggle/working/segmentation_sweep_results.zip. Called after EVERY
    training cell below, not just at the end -- if the run gets cut short
    partway through the 18 combos, whatever completed so far is still
    cleanly consolidated and zipped, ready to download.

    IMPORTANT (added after a real Kaggle disk-quota crash, "Your notebook
    tried to use more disk space than is available", 20.93GB used, failed
    5h40m into a real run): each of the 18 training scripts can write up to
    3 full checkpoint files at fp32 (best-overall + one per loss function),
    and none of that is ever deleted between combos -- for the larger
    architectures (ConvNeXt-Large ~203M params, Swin-Large ~234M, etc.)
    those add up to hundreds of MB to ~1GB EACH. Originally this function
    copied Segmentation/outputs/ into /kaggle/working/outputs/ and left the
    source in place, so between the untouched source, the mirrored copy,
    and the zip made from that copy, roughly 3 copies of everything
    produced so far existed on disk simultaneously -- comfortably enough to
    blow a ~20GB quota partway through the Mid/Strong tiers. Now the
    source is deleted right after it's safely copied into
    /kaggle/working/outputs/, which becomes the single accumulating copy
    (plus the zip made from it) -- every training script recreates
    Segmentation/outputs/{checkpoints,logs,plots}/ fresh via its own
    mkdir(parents=True, exist_ok=True) on its next run, so nothing is lost
    by clearing the source here.
    """
    results_dir = Path("/kaggle/working/outputs")
    results_dir.mkdir(parents=True, exist_ok=True)
    for sub in ["checkpoints", "logs", "plots"]:
        src = Path("Segmentation/outputs") / sub
        if src.exists():
            shutil.copytree(src, results_dir / sub, dirs_exist_ok=True)
            shutil.rmtree(src)
    archive_path = shutil.make_archive("/kaggle/working/segmentation_sweep_results", "zip", root_dir=str(results_dir))
    n_files = sum(1 for f in results_dir.rglob("*") if f.is_file())
    print(f"[sync_outputs] {n_files} files consolidated under {results_dir}, zipped to {archive_path}")


sync_outputs()  # harmless no-op now (nothing produced yet), confirms the function works before training starts
# Out:
# [sync_outputs] 0 files consolidated under /kaggle/working/outputs, zipped to /kaggle/working/segmentation_sweep_results.zip

# %% [markdown]
# ### K-fold re-training — Mid tier (4 combos)

# %%
# Mid tier, combo 1/4 -- ResNet101 DeepLabV3+ (CNN, ~45.7M), palpebral (3 folds, fixed best hyperparameters)
# !python Segmentation/scripts/train_pretrained_kfold/train_kfold_cnn_mid_resnet101_deeplabv3plus_palpebral.py
sync_outputs()
# Out:
# Using device: cuda
# Model: cnn_mid_resnet101_deeplabv3plus_palpebral (K-fold re-training, fixed hyperparameters)
# tissue_type=palpebral image_size=256
# learning_rate=0.000684792009557478 weight_decay=2.62108787826544e-06 loss_fn=focal_tversky
# n_folds=3 MAX_EPOCHS=250 EARLY_STOPPING_PATIENCE=7 BATCH_SIZE=32
# Pool (train+val, aligned): 170 patients
#
# === cnn_mid_resnet101_deeplabv3plus_palpebral | Fold 1/3: train=113 val=57 ===
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100%|██████████████████████████████| 156/156 [00:00<00:00, 946kB/s]
# model.safetensors: 100%|█████████████████████| 179M/179M [00:02<00:00, 67.7MB/s]
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch   1/250 - train_loss=0.7856 val_loss=0.8536 val_dice=0.1302 val_iou=0.0702 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch   2/250 - train_loss=0.6355 val_loss=0.8251 val_dice=0.2359 val_iou=0.1353 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch   3/250 - train_loss=0.5532 val_loss=0.7937 val_dice=0.3200 val_iou=0.1944 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch   4/250 - train_loss=0.4817 val_loss=0.7314 val_dice=0.3668 val_iou=0.2290 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch   5/250 - train_loss=0.4152 val_loss=0.6950 val_dice=0.4330 val_iou=0.2818 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch   6/250 - train_loss=0.3487 val_loss=0.6146 val_dice=0.5794 val_iou=0.4162 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch   7/250 - train_loss=0.2936 val_loss=0.4832 val_dice=0.6954 val_iou=0.5428 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch   8/250 - train_loss=0.2461 val_loss=0.4121 val_dice=0.6817 val_iou=0.5266 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch   9/250 - train_loss=0.2038 val_loss=0.3316 val_dice=0.6926 val_iou=0.5384 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  10/250 - train_loss=0.1802 val_loss=0.2332 val_dice=0.7902 val_iou=0.6612 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  11/250 - train_loss=0.1532 val_loss=0.2004 val_dice=0.7444 val_iou=0.6005 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  12/250 - train_loss=0.1370 val_loss=0.1820 val_dice=0.7740 val_iou=0.6407 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  13/250 - train_loss=0.1251 val_loss=0.1747 val_dice=0.7489 val_iou=0.6066 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  14/250 - train_loss=0.1122 val_loss=0.1538 val_dice=0.8043 val_iou=0.6818 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  15/250 - train_loss=0.0995 val_loss=0.1419 val_dice=0.8028 val_iou=0.6787 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  16/250 - train_loss=0.0916 val_loss=0.1247 val_dice=0.8080 val_iou=0.6871 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  17/250 - train_loss=0.0839 val_loss=0.1185 val_dice=0.7900 val_iou=0.6619 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  18/250 - train_loss=0.0775 val_loss=0.1186 val_dice=0.7863 val_iou=0.6582 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  19/250 - train_loss=0.0757 val_loss=0.1086 val_dice=0.7949 val_iou=0.6680 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  20/250 - train_loss=0.0718 val_loss=0.0999 val_dice=0.8174 val_iou=0.6981 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  21/250 - train_loss=0.0678 val_loss=0.1065 val_dice=0.8212 val_iou=0.7052 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  22/250 - train_loss=0.0664 val_loss=0.0971 val_dice=0.8092 val_iou=0.6880 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  23/250 - train_loss=0.0630 val_loss=0.0999 val_dice=0.8300 val_iou=0.7159 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  24/250 - train_loss=0.0603 val_loss=0.1310 val_dice=0.8041 val_iou=0.6907 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  25/250 - train_loss=0.0585 val_loss=0.0988 val_dice=0.8154 val_iou=0.6961 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  26/250 - train_loss=0.0600 val_loss=0.0970 val_dice=0.8117 val_iou=0.6914 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  27/250 - train_loss=0.0579 val_loss=0.1041 val_dice=0.8145 val_iou=0.6935 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  28/250 - train_loss=0.0551 val_loss=0.1020 val_dice=0.8141 val_iou=0.6962 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  29/250 - train_loss=0.0553 val_loss=0.1178 val_dice=0.8077 val_iou=0.6917 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  30/250 - train_loss=0.0529 val_loss=0.1010 val_dice=0.8265 val_iou=0.7113 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  31/250 - train_loss=0.0513 val_loss=0.0997 val_dice=0.8270 val_iou=0.7125 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  32/250 - train_loss=0.0506 val_loss=0.0900 val_dice=0.8277 val_iou=0.7133 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  33/250 - train_loss=0.0459 val_loss=0.0939 val_dice=0.8251 val_iou=0.7099 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  34/250 - train_loss=0.0458 val_loss=0.0990 val_dice=0.8229 val_iou=0.7067 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  35/250 - train_loss=0.0445 val_loss=0.0919 val_dice=0.8259 val_iou=0.7104 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  36/250 - train_loss=0.0429 val_loss=0.0874 val_dice=0.8268 val_iou=0.7118 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  37/250 - train_loss=0.0415 val_loss=0.0889 val_dice=0.8340 val_iou=0.7214 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  38/250 - train_loss=0.0437 val_loss=0.0817 val_dice=0.8320 val_iou=0.7190 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  39/250 - train_loss=0.0438 val_loss=0.0896 val_dice=0.8344 val_iou=0.7218 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  40/250 - train_loss=0.0424 val_loss=0.0903 val_dice=0.8232 val_iou=0.7062 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  41/250 - train_loss=0.0431 val_loss=0.0885 val_dice=0.8352 val_iou=0.7234 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  42/250 - train_loss=0.0416 val_loss=0.0854 val_dice=0.8376 val_iou=0.7271 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  43/250 - train_loss=0.0393 val_loss=0.0856 val_dice=0.8310 val_iou=0.7177 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  44/250 - train_loss=0.0392 val_loss=0.0859 val_dice=0.8315 val_iou=0.7182 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1/3] Epoch  45/250 - train_loss=0.0365 val_loss=0.0899 val_dice=0.8337 val_iou=0.7206 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 1] Early stopping at epoch 45 (no val_loss improvement for 7 epochs).
# --- Fold 1 test-set evaluation (best_cnn_mid_resnet101_deeplabv3plus_palpebral_fold1.pth) ---
# Fold 1 test Dice=0.8419 IoU=0.7345 HD95=11.18px
#
# === cnn_mid_resnet101_deeplabv3plus_palpebral | Fold 2/3: train=113 val=57 ===
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 2/3] Epoch   1/250 - train_loss=0.7879 val_loss=0.8348 val_dice=0.1203 val_iou=0.0644 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 2/3] Epoch   2/250 - train_loss=0.6700 val_loss=0.8266 val_dice=0.1011 val_iou=0.0539 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 2/3] Epoch   3/250 - train_loss=0.6007 val_loss=0.8258 val_dice=0.0854 val_iou=0.0451 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 2/3] Epoch   4/250 - train_loss=0.5509 val_loss=0.7239 val_dice=0.3597 val_iou=0.2256 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 2/3] Epoch   5/250 - train_loss=0.4929 val_loss=0.6627 val_dice=0.4550 val_iou=0.3094 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 2/3] Epoch   6/250 - train_loss=0.4467 val_loss=0.6164 val_dice=0.4848 val_iou=0.3286 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 2/3] Epoch   7/250 - train_loss=0.4237 val_loss=0.6739 val_dice=0.3052 val_iou=0.1970 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 2/3] Epoch   8/250 - train_loss=0.3921 val_loss=0.7537 val_dice=0.1805 val_iou=0.1035 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 2/3] Epoch   9/250 - train_loss=0.3417 val_loss=0.7564 val_dice=0.1532 val_iou=0.0860 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 2/3] Epoch  10/250 - train_loss=0.3108 val_loss=0.7101 val_dice=0.2685 val_iou=0.1824 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 2/3] Epoch  11/250 - train_loss=0.2975 val_loss=0.7161 val_dice=0.2625 val_iou=0.1820 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 2/3] Epoch  12/250 - train_loss=0.3052 val_loss=0.8282 val_dice=0.1004 val_iou=0.0584 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 2/3] Epoch  13/250 - train_loss=0.2809 val_loss=0.6644 val_dice=0.3117 val_iou=0.2334 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 2] Early stopping at epoch 13 (no val_loss improvement for 7 epochs).
# --- Fold 2 test-set evaluation (best_cnn_mid_resnet101_deeplabv3plus_palpebral_fold2.pth) ---
# Fold 2 test Dice=0.4931 IoU=0.3380 HD95=54.86px
#
# === cnn_mid_resnet101_deeplabv3plus_palpebral | Fold 3/3: train=114 val=56 ===
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch   1/250 - train_loss=0.7680 val_loss=0.8355 val_dice=0.2231 val_iou=0.1268 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch   2/250 - train_loss=0.6435 val_loss=0.7546 val_dice=0.2822 val_iou=0.1666 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch   3/250 - train_loss=0.5710 val_loss=0.7488 val_dice=0.4128 val_iou=0.2654 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch   4/250 - train_loss=0.4983 val_loss=0.7756 val_dice=0.6726 val_iou=0.5159 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch   5/250 - train_loss=0.4592 val_loss=0.6673 val_dice=0.4275 val_iou=0.2772 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch   6/250 - train_loss=0.4046 val_loss=0.5998 val_dice=0.4977 val_iou=0.3388 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch   7/250 - train_loss=0.3390 val_loss=0.5204 val_dice=0.6452 val_iou=0.4857 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch   8/250 - train_loss=0.2808 val_loss=0.5330 val_dice=0.6460 val_iou=0.4854 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch   9/250 - train_loss=0.2387 val_loss=0.4518 val_dice=0.6596 val_iou=0.4994 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  10/250 - train_loss=0.1952 val_loss=0.4017 val_dice=0.6867 val_iou=0.5301 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  11/250 - train_loss=0.1678 val_loss=0.2501 val_dice=0.7440 val_iou=0.5998 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  12/250 - train_loss=0.1466 val_loss=0.1700 val_dice=0.8105 val_iou=0.6868 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  13/250 - train_loss=0.1344 val_loss=0.1421 val_dice=0.8206 val_iou=0.7007 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  14/250 - train_loss=0.1184 val_loss=0.1309 val_dice=0.8252 val_iou=0.7074 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  15/250 - train_loss=0.1109 val_loss=0.1226 val_dice=0.8256 val_iou=0.7080 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  16/250 - train_loss=0.1013 val_loss=0.1139 val_dice=0.8402 val_iou=0.7292 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  17/250 - train_loss=0.0931 val_loss=0.1157 val_dice=0.8222 val_iou=0.7037 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  18/250 - train_loss=0.0889 val_loss=0.0956 val_dice=0.8407 val_iou=0.7289 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  19/250 - train_loss=0.0828 val_loss=0.0945 val_dice=0.8448 val_iou=0.7350 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  20/250 - train_loss=0.0784 val_loss=0.0889 val_dice=0.8465 val_iou=0.7385 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  21/250 - train_loss=0.0750 val_loss=0.0953 val_dice=0.8400 val_iou=0.7279 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  22/250 - train_loss=0.0708 val_loss=0.0942 val_dice=0.8454 val_iou=0.7362 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  23/250 - train_loss=0.0712 val_loss=0.1130 val_dice=0.8365 val_iou=0.7240 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  24/250 - train_loss=0.0715 val_loss=0.1109 val_dice=0.8193 val_iou=0.6987 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  25/250 - train_loss=0.0681 val_loss=0.0945 val_dice=0.8313 val_iou=0.7156 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  26/250 - train_loss=0.0660 val_loss=0.0901 val_dice=0.8415 val_iou=0.7304 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  27/250 - train_loss=0.0625 val_loss=0.0868 val_dice=0.8470 val_iou=0.7383 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  28/250 - train_loss=0.0597 val_loss=0.0914 val_dice=0.8491 val_iou=0.7421 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  29/250 - train_loss=0.0573 val_loss=0.0862 val_dice=0.8515 val_iou=0.7464 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  30/250 - train_loss=0.0552 val_loss=0.0908 val_dice=0.8509 val_iou=0.7450 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  31/250 - train_loss=0.0543 val_loss=0.0882 val_dice=0.8507 val_iou=0.7444 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  32/250 - train_loss=0.0533 val_loss=0.0845 val_dice=0.8505 val_iou=0.7439 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  33/250 - train_loss=0.0516 val_loss=0.0996 val_dice=0.8435 val_iou=0.7351 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  34/250 - train_loss=0.0484 val_loss=0.0965 val_dice=0.8452 val_iou=0.7367 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  35/250 - train_loss=0.0499 val_loss=0.0821 val_dice=0.8552 val_iou=0.7515 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  36/250 - train_loss=0.0516 val_loss=0.0897 val_dice=0.8444 val_iou=0.7354 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  37/250 - train_loss=0.0502 val_loss=0.0889 val_dice=0.8467 val_iou=0.7384 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  38/250 - train_loss=0.0477 val_loss=0.0810 val_dice=0.8512 val_iou=0.7454 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  39/250 - train_loss=0.0487 val_loss=0.0938 val_dice=0.8433 val_iou=0.7336 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  40/250 - train_loss=0.0458 val_loss=0.0899 val_dice=0.8455 val_iou=0.7370 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  41/250 - train_loss=0.0447 val_loss=0.0899 val_dice=0.8436 val_iou=0.7341 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  42/250 - train_loss=0.0472 val_loss=0.1011 val_dice=0.8374 val_iou=0.7252 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  43/250 - train_loss=0.0459 val_loss=0.0885 val_dice=0.8474 val_iou=0.7401 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  44/250 - train_loss=0.0441 val_loss=0.1003 val_dice=0.8457 val_iou=0.7378 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3/3] Epoch  45/250 - train_loss=0.0423 val_loss=0.0965 val_dice=0.8468 val_iou=0.7395 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_palpebral | fold 3] Early stopping at epoch 45 (no val_loss improvement for 7 epochs).
# --- Fold 3 test-set evaluation (best_cnn_mid_resnet101_deeplabv3plus_palpebral_fold3.pth) ---
# Fold 3 test Dice=0.8453 IoU=0.7391 HD95=14.09px
#
# --- Measuring architecture properties (params, inference latency) ---
# Parameters: 45,669,713
# Inference latency (batch_size=1, 256x256): 12.96 ms
#
# Saved per-fold summary to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/cnn_mid_resnet101_deeplabv3plus_palpebral_kfold_folds.csv
#
# --- Aggregate across folds (mean +/- std) ---
#   dice       = 0.7268 +/- 0.2024
#   iou        = 0.6039 +/- 0.2303
#   precision  = 0.6620 +/- 0.2761
#   recall     = 0.9081 +/- 0.0465
#   hd95       = 26.7097 +/- 24.4200
# Saved per-patient-per-fold test metrics to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/cnn_mid_resnet101_deeplabv3plus_palpebral_kfold_test_per_patient.csv
# Saved K-fold summary to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/cnn_mid_resnet101_deeplabv3plus_palpebral_kfold_summary.json
# Saved 5 plots to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/plots:
#   cnn_mid_resnet101_deeplabv3plus_palpebral_kfold_mean_curve.png
#   cnn_mid_resnet101_deeplabv3plus_palpebral_fold_dice_distribution.png
#   cnn_mid_resnet101_deeplabv3plus_palpebral_test_summary.png
#   cnn_mid_resnet101_deeplabv3plus_palpebral_test_by_country.png
#   cnn_mid_resnet101_deeplabv3plus_palpebral_test_per_patient_dice.png
# [sync_outputs] 11 files consolidated under /kaggle/working/outputs, zipped to /kaggle/working/segmentation_sweep_results.zip

# %%
# Mid tier, combo 2/4 -- ResNet101 DeepLabV3+ (CNN, ~45.7M), forniceal_palpebral (3 folds, fixed best hyperparameters)
# !python Segmentation/scripts/train_pretrained_kfold/train_kfold_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral.py
sync_outputs()
# Out:
# Using device: cuda
# Model: cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral (K-fold re-training, fixed hyperparameters)
# tissue_type=forniceal_palpebral image_size=256
# learning_rate=0.000684792009557478 weight_decay=2.62108787826544e-06 loss_fn=focal_tversky
# n_folds=3 MAX_EPOCHS=250 EARLY_STOPPING_PATIENCE=7 BATCH_SIZE=32
# Pool (train+val, aligned): 178 patients
#
# === cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Fold 1/3: train=118 val=60 ===
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch   1/250 - train_loss=0.5503 val_loss=0.6695 val_dice=0.5370 val_iou=0.3745 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch   2/250 - train_loss=0.3636 val_loss=0.5150 val_dice=0.5243 val_iou=0.3611 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch   3/250 - train_loss=0.2865 val_loss=0.4918 val_dice=0.6875 val_iou=0.5316 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch   4/250 - train_loss=0.2505 val_loss=0.4925 val_dice=0.5642 val_iou=0.3993 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch   5/250 - train_loss=0.2260 val_loss=0.4150 val_dice=0.6703 val_iou=0.5130 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch   6/250 - train_loss=0.1821 val_loss=0.3635 val_dice=0.7535 val_iou=0.6137 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch   7/250 - train_loss=0.1524 val_loss=0.3171 val_dice=0.7229 val_iou=0.5737 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch   8/250 - train_loss=0.1269 val_loss=0.2262 val_dice=0.8175 val_iou=0.6992 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch   9/250 - train_loss=0.1087 val_loss=0.1722 val_dice=0.8377 val_iou=0.7274 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  10/250 - train_loss=0.0961 val_loss=0.1279 val_dice=0.8655 val_iou=0.7686 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  11/250 - train_loss=0.0891 val_loss=0.1142 val_dice=0.8527 val_iou=0.7499 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  12/250 - train_loss=0.0767 val_loss=0.1028 val_dice=0.8777 val_iou=0.7878 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  13/250 - train_loss=0.0693 val_loss=0.0904 val_dice=0.8535 val_iou=0.7507 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  14/250 - train_loss=0.0647 val_loss=0.0757 val_dice=0.8905 val_iou=0.8074 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  15/250 - train_loss=0.0561 val_loss=0.0726 val_dice=0.8862 val_iou=0.8003 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  16/250 - train_loss=0.0523 val_loss=0.0641 val_dice=0.8913 val_iou=0.8087 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  17/250 - train_loss=0.0495 val_loss=0.0653 val_dice=0.8986 val_iou=0.8200 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  18/250 - train_loss=0.0460 val_loss=0.0648 val_dice=0.8721 val_iou=0.7786 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  19/250 - train_loss=0.0439 val_loss=0.0633 val_dice=0.8877 val_iou=0.8038 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  20/250 - train_loss=0.0411 val_loss=0.0573 val_dice=0.8901 val_iou=0.8072 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  21/250 - train_loss=0.0387 val_loss=0.0533 val_dice=0.8967 val_iou=0.8174 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  22/250 - train_loss=0.0366 val_loss=0.0847 val_dice=0.8853 val_iou=0.8005 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  23/250 - train_loss=0.0354 val_loss=0.0519 val_dice=0.8943 val_iou=0.8138 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  24/250 - train_loss=0.0358 val_loss=0.0575 val_dice=0.8863 val_iou=0.8013 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  25/250 - train_loss=0.0342 val_loss=0.0526 val_dice=0.8945 val_iou=0.8133 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  26/250 - train_loss=0.0326 val_loss=0.0510 val_dice=0.8880 val_iou=0.8033 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  27/250 - train_loss=0.0312 val_loss=0.0524 val_dice=0.9035 val_iou=0.8273 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  28/250 - train_loss=0.0294 val_loss=0.0482 val_dice=0.8994 val_iou=0.8214 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  29/250 - train_loss=0.0285 val_loss=0.0525 val_dice=0.8912 val_iou=0.8083 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  30/250 - train_loss=0.0292 val_loss=0.0483 val_dice=0.8937 val_iou=0.8125 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  31/250 - train_loss=0.0272 val_loss=0.0501 val_dice=0.9063 val_iou=0.8324 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  32/250 - train_loss=0.0251 val_loss=0.0476 val_dice=0.8991 val_iou=0.8209 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  33/250 - train_loss=0.0251 val_loss=0.0498 val_dice=0.8988 val_iou=0.8205 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  34/250 - train_loss=0.0233 val_loss=0.0495 val_dice=0.9028 val_iou=0.8271 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  35/250 - train_loss=0.0227 val_loss=0.0451 val_dice=0.9040 val_iou=0.8290 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  36/250 - train_loss=0.0205 val_loss=0.0563 val_dice=0.9011 val_iou=0.8238 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  37/250 - train_loss=0.0227 val_loss=0.0469 val_dice=0.9060 val_iou=0.8321 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  38/250 - train_loss=0.0207 val_loss=0.0520 val_dice=0.9061 val_iou=0.8318 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  39/250 - train_loss=0.0196 val_loss=0.0437 val_dice=0.9048 val_iou=0.8301 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  40/250 - train_loss=0.0203 val_loss=0.0426 val_dice=0.9059 val_iou=0.8315 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  41/250 - train_loss=0.0188 val_loss=0.0472 val_dice=0.9114 val_iou=0.8404 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  42/250 - train_loss=0.0189 val_loss=0.0437 val_dice=0.9020 val_iou=0.8259 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  43/250 - train_loss=0.0197 val_loss=0.0448 val_dice=0.9061 val_iou=0.8325 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  44/250 - train_loss=0.0179 val_loss=0.0453 val_dice=0.9083 val_iou=0.8357 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  45/250 - train_loss=0.0168 val_loss=0.0414 val_dice=0.9061 val_iou=0.8325 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  46/250 - train_loss=0.0163 val_loss=0.0419 val_dice=0.9061 val_iou=0.8323 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  47/250 - train_loss=0.0160 val_loss=0.0430 val_dice=0.9096 val_iou=0.8379 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  48/250 - train_loss=0.0163 val_loss=0.0435 val_dice=0.9109 val_iou=0.8398 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  49/250 - train_loss=0.0157 val_loss=0.0422 val_dice=0.9076 val_iou=0.8344 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  50/250 - train_loss=0.0149 val_loss=0.0424 val_dice=0.9102 val_iou=0.8387 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  51/250 - train_loss=0.0145 val_loss=0.0439 val_dice=0.9116 val_iou=0.8409 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1/3] Epoch  52/250 - train_loss=0.0140 val_loss=0.0437 val_dice=0.9109 val_iou=0.8397 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 1] Early stopping at epoch 52 (no val_loss improvement for 7 epochs).
# --- Fold 1 test-set evaluation (best_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_fold1.pth) ---
# Fold 1 test Dice=0.9272 IoU=0.8653 HD95=8.99px
#
# === cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Fold 2/3: train=119 val=59 ===
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch   1/250 - train_loss=0.5597 val_loss=0.6590 val_dice=0.3760 val_iou=0.2349 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch   2/250 - train_loss=0.3821 val_loss=0.5088 val_dice=0.5270 val_iou=0.3637 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch   3/250 - train_loss=0.3118 val_loss=0.4719 val_dice=0.6710 val_iou=0.5105 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch   4/250 - train_loss=0.2660 val_loss=0.4273 val_dice=0.7116 val_iou=0.5593 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch   5/250 - train_loss=0.2251 val_loss=0.4096 val_dice=0.7549 val_iou=0.6134 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch   6/250 - train_loss=0.1993 val_loss=0.3777 val_dice=0.6696 val_iou=0.5074 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch   7/250 - train_loss=0.1618 val_loss=0.2946 val_dice=0.8088 val_iou=0.6839 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch   8/250 - train_loss=0.1324 val_loss=0.2405 val_dice=0.8091 val_iou=0.6842 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch   9/250 - train_loss=0.1147 val_loss=0.1773 val_dice=0.8559 val_iou=0.7515 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  10/250 - train_loss=0.0982 val_loss=0.1406 val_dice=0.8256 val_iou=0.7083 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  11/250 - train_loss=0.0905 val_loss=0.1073 val_dice=0.8878 val_iou=0.8026 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  12/250 - train_loss=0.0793 val_loss=0.1021 val_dice=0.8553 val_iou=0.7526 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  13/250 - train_loss=0.0726 val_loss=0.0951 val_dice=0.8529 val_iou=0.7468 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  14/250 - train_loss=0.0649 val_loss=0.0727 val_dice=0.8802 val_iou=0.7893 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  15/250 - train_loss=0.0605 val_loss=0.0699 val_dice=0.8880 val_iou=0.8038 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  16/250 - train_loss=0.0542 val_loss=0.0685 val_dice=0.8740 val_iou=0.7822 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  17/250 - train_loss=0.0533 val_loss=0.0629 val_dice=0.8822 val_iou=0.7936 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  18/250 - train_loss=0.0488 val_loss=0.0718 val_dice=0.8840 val_iou=0.7962 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  19/250 - train_loss=0.0467 val_loss=0.0567 val_dice=0.8853 val_iou=0.7979 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  20/250 - train_loss=0.0410 val_loss=0.0601 val_dice=0.9066 val_iou=0.8322 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  21/250 - train_loss=0.0392 val_loss=0.0502 val_dice=0.8927 val_iou=0.8104 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  22/250 - train_loss=0.0386 val_loss=0.0488 val_dice=0.8965 val_iou=0.8164 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  23/250 - train_loss=0.0340 val_loss=0.0512 val_dice=0.9096 val_iou=0.8369 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  24/250 - train_loss=0.0333 val_loss=0.0464 val_dice=0.9030 val_iou=0.8265 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  25/250 - train_loss=0.0327 val_loss=0.0480 val_dice=0.9083 val_iou=0.8347 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  26/250 - train_loss=0.0307 val_loss=0.0456 val_dice=0.9076 val_iou=0.8335 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  27/250 - train_loss=0.0286 val_loss=0.0468 val_dice=0.9041 val_iou=0.8279 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  28/250 - train_loss=0.0262 val_loss=0.0459 val_dice=0.9136 val_iou=0.8435 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  29/250 - train_loss=0.0264 val_loss=0.0444 val_dice=0.8989 val_iou=0.8198 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  30/250 - train_loss=0.0256 val_loss=0.0425 val_dice=0.9056 val_iou=0.8309 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  31/250 - train_loss=0.0247 val_loss=0.0450 val_dice=0.8911 val_iou=0.8077 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  32/250 - train_loss=0.0267 val_loss=0.0433 val_dice=0.9090 val_iou=0.8358 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  33/250 - train_loss=0.0251 val_loss=0.0471 val_dice=0.9080 val_iou=0.8342 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  34/250 - train_loss=0.0242 val_loss=0.0449 val_dice=0.9002 val_iou=0.8228 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  35/250 - train_loss=0.0227 val_loss=0.0425 val_dice=0.9064 val_iou=0.8315 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  36/250 - train_loss=0.0224 val_loss=0.0415 val_dice=0.9072 val_iou=0.8330 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  37/250 - train_loss=0.0206 val_loss=0.0413 val_dice=0.9076 val_iou=0.8336 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  38/250 - train_loss=0.0197 val_loss=0.0436 val_dice=0.9065 val_iou=0.8317 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  39/250 - train_loss=0.0197 val_loss=0.0410 val_dice=0.9075 val_iou=0.8335 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  40/250 - train_loss=0.0192 val_loss=0.0439 val_dice=0.9101 val_iou=0.8377 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  41/250 - train_loss=0.0189 val_loss=0.0423 val_dice=0.9090 val_iou=0.8361 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  42/250 - train_loss=0.0183 val_loss=0.0415 val_dice=0.9096 val_iou=0.8369 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  43/250 - train_loss=0.0180 val_loss=0.0407 val_dice=0.9080 val_iou=0.8344 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  44/250 - train_loss=0.0176 val_loss=0.0416 val_dice=0.9097 val_iou=0.8370 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  45/250 - train_loss=0.0173 val_loss=0.0416 val_dice=0.9095 val_iou=0.8364 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  46/250 - train_loss=0.0174 val_loss=0.0405 val_dice=0.9091 val_iou=0.8357 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  47/250 - train_loss=0.0163 val_loss=0.0424 val_dice=0.9119 val_iou=0.8403 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  48/250 - train_loss=0.0177 val_loss=0.0396 val_dice=0.9110 val_iou=0.8390 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  49/250 - train_loss=0.0165 val_loss=0.0418 val_dice=0.9117 val_iou=0.8403 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  50/250 - train_loss=0.0171 val_loss=0.0409 val_dice=0.9044 val_iou=0.8281 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  51/250 - train_loss=0.0181 val_loss=0.0385 val_dice=0.9108 val_iou=0.8387 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  52/250 - train_loss=0.0163 val_loss=0.0440 val_dice=0.9123 val_iou=0.8411 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  53/250 - train_loss=0.0163 val_loss=0.0396 val_dice=0.9093 val_iou=0.8363 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  54/250 - train_loss=0.0158 val_loss=0.0389 val_dice=0.9060 val_iou=0.8309 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  55/250 - train_loss=0.0160 val_loss=0.0411 val_dice=0.9117 val_iou=0.8402 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  56/250 - train_loss=0.0159 val_loss=0.0397 val_dice=0.9095 val_iou=0.8368 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  57/250 - train_loss=0.0150 val_loss=0.0404 val_dice=0.9086 val_iou=0.8353 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2/3] Epoch  58/250 - train_loss=0.0149 val_loss=0.0414 val_dice=0.9094 val_iou=0.8365 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 2] Early stopping at epoch 58 (no val_loss improvement for 7 epochs).
# --- Fold 2 test-set evaluation (best_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_fold2.pth) ---
# Fold 2 test Dice=0.9217 IoU=0.8567 HD95=9.26px
#
# === cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Fold 3/3: train=119 val=59 ===
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch   1/250 - train_loss=0.5690 val_loss=0.6639 val_dice=0.5728 val_iou=0.4075 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch   2/250 - train_loss=0.3540 val_loss=0.5527 val_dice=0.6338 val_iou=0.4688 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch   3/250 - train_loss=0.2833 val_loss=0.4972 val_dice=0.6875 val_iou=0.5272 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch   4/250 - train_loss=0.2313 val_loss=0.4609 val_dice=0.7231 val_iou=0.5711 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch   5/250 - train_loss=0.1911 val_loss=0.4236 val_dice=0.8155 val_iou=0.6911 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch   6/250 - train_loss=0.1595 val_loss=0.3432 val_dice=0.8133 val_iou=0.6888 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch   7/250 - train_loss=0.1350 val_loss=0.2703 val_dice=0.8160 val_iou=0.6926 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch   8/250 - train_loss=0.1160 val_loss=0.2079 val_dice=0.8372 val_iou=0.7229 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch   9/250 - train_loss=0.0960 val_loss=0.1527 val_dice=0.8790 val_iou=0.7857 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  10/250 - train_loss=0.0850 val_loss=0.1184 val_dice=0.8513 val_iou=0.7437 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  11/250 - train_loss=0.0760 val_loss=0.0946 val_dice=0.8903 val_iou=0.8045 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  12/250 - train_loss=0.0662 val_loss=0.1014 val_dice=0.8375 val_iou=0.7234 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  13/250 - train_loss=0.0605 val_loss=0.0734 val_dice=0.9053 val_iou=0.8285 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  14/250 - train_loss=0.0578 val_loss=0.0726 val_dice=0.8685 val_iou=0.7708 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  15/250 - train_loss=0.0566 val_loss=0.0730 val_dice=0.8677 val_iou=0.7698 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  16/250 - train_loss=0.0515 val_loss=0.0583 val_dice=0.8903 val_iou=0.8050 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  17/250 - train_loss=0.0474 val_loss=0.0546 val_dice=0.9010 val_iou=0.8215 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  18/250 - train_loss=0.0433 val_loss=0.0532 val_dice=0.9053 val_iou=0.8292 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  19/250 - train_loss=0.0406 val_loss=0.0496 val_dice=0.8979 val_iou=0.8169 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  20/250 - train_loss=0.0372 val_loss=0.0478 val_dice=0.9002 val_iou=0.8207 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  21/250 - train_loss=0.0357 val_loss=0.0454 val_dice=0.9048 val_iou=0.8281 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  22/250 - train_loss=0.0342 val_loss=0.0468 val_dice=0.9140 val_iou=0.8434 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  23/250 - train_loss=0.0317 val_loss=0.0425 val_dice=0.9024 val_iou=0.8242 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  24/250 - train_loss=0.0328 val_loss=0.0484 val_dice=0.9106 val_iou=0.8376 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  25/250 - train_loss=0.0306 val_loss=0.0431 val_dice=0.9033 val_iou=0.8254 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  26/250 - train_loss=0.0307 val_loss=0.0458 val_dice=0.9099 val_iou=0.8364 lr=6.85e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  27/250 - train_loss=0.0282 val_loss=0.0436 val_dice=0.9037 val_iou=0.8269 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  28/250 - train_loss=0.0253 val_loss=0.0415 val_dice=0.9137 val_iou=0.8425 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  29/250 - train_loss=0.0256 val_loss=0.0431 val_dice=0.9107 val_iou=0.8381 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  30/250 - train_loss=0.0253 val_loss=0.0439 val_dice=0.9109 val_iou=0.8378 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  31/250 - train_loss=0.0246 val_loss=0.0402 val_dice=0.9093 val_iou=0.8357 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  32/250 - train_loss=0.0235 val_loss=0.0407 val_dice=0.9165 val_iou=0.8474 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  33/250 - train_loss=0.0222 val_loss=0.0399 val_dice=0.9118 val_iou=0.8400 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  34/250 - train_loss=0.0228 val_loss=0.0388 val_dice=0.9143 val_iou=0.8437 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  35/250 - train_loss=0.0218 val_loss=0.0377 val_dice=0.9117 val_iou=0.8396 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  36/250 - train_loss=0.0212 val_loss=0.0422 val_dice=0.9145 val_iou=0.8441 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  37/250 - train_loss=0.0204 val_loss=0.0412 val_dice=0.9144 val_iou=0.8440 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  38/250 - train_loss=0.0203 val_loss=0.0394 val_dice=0.9128 val_iou=0.8416 lr=3.42e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  39/250 - train_loss=0.0201 val_loss=0.0395 val_dice=0.9161 val_iou=0.8469 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  40/250 - train_loss=0.0193 val_loss=0.0380 val_dice=0.9136 val_iou=0.8426 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  41/250 - train_loss=0.0188 val_loss=0.0386 val_dice=0.9121 val_iou=0.8403 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3/3] Epoch  42/250 - train_loss=0.0190 val_loss=0.0396 val_dice=0.9149 val_iou=0.8450 lr=1.71e-04
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | fold 3] Early stopping at epoch 42 (no val_loss improvement for 7 epochs).
# --- Fold 3 test-set evaluation (best_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_fold3.pth) ---
# Fold 3 test Dice=0.9261 IoU=0.8637 HD95=9.31px
#
# --- Measuring architecture properties (params, inference latency) ---
# Parameters: 45,669,713
# Inference latency (batch_size=1, 256x256): 12.95 ms
#
# Saved per-fold summary to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_kfold_folds.csv
#
# --- Aggregate across folds (mean +/- std) ---
#   dice       = 0.9250 +/- 0.0029
#   iou        = 0.8619 +/- 0.0046
#   precision  = 0.9164 +/- 0.0053
#   recall     = 0.9378 +/- 0.0111
#   hd95       = 9.1854 +/- 0.1715
# Saved per-patient-per-fold test metrics to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_kfold_test_per_patient.csv
# Saved K-fold summary to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_kfold_summary.json
# Saved 5 plots to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/plots:
#   cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_kfold_mean_curve.png
#   cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_fold_dice_distribution.png
#   cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_test_summary.png
#   cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_test_by_country.png
#   cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_test_per_patient_dice.png
# [sync_outputs] 22 files consolidated under /kaggle/working/outputs, zipped to /kaggle/working/segmentation_sweep_results.zip

# %%
# Mid tier, combo 3/4 -- CoAtNet-2 U-Net (Hybrid, ~78.0M), palpebral (3 folds, fixed best hyperparameters)
# !python Segmentation/scripts/train_pretrained_kfold/train_kfold_hybrid_mid_coatnet2_unet_palpebral.py
sync_outputs()
# Out:
# Using device: cuda
# Model: hybrid_mid_coatnet2_unet_palpebral (K-fold re-training, fixed hyperparameters)
# tissue_type=palpebral image_size=224
# learning_rate=0.000684792009557478 weight_decay=2.62108787826544e-06 loss_fn=focal_tversky
# n_folds=3 MAX_EPOCHS=250 EARLY_STOPPING_PATIENCE=7 BATCH_SIZE=32
# Pool (train+val, aligned): 170 patients
#
# === hybrid_mid_coatnet2_unet_palpebral | Fold 1/3: train=113 val=57 ===
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors: 100%|█████████████████████| 296M/296M [00:08<00:00, 35.9MB/s]
# Traceback (most recent call last):
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/train_pretrained_kfold/train_kfold_hybrid_mid_coatnet2_unet_palpebral.py", line 24, in <module>
#     run_kfold_study(
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/train_pretrained_kfold/kfold_engine.py", line 184, in run_kfold_study
#     train_loss = train_one_epoch(model, train_loader, optimizer, criterion, DEVICE)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/trainer_engine.py", line 187, in train_one_epoch
#     logits = model(images)
#              ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/segmentation_models_pytorch/base/model.py", line 67, in forward
#     decoder_output = self.decoder(features)
#                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/segmentation_models_pytorch/decoders/unet/decoder.py", line 168, in forward
#     x = decoder_block(x, height, width, skip_connection=skip_connection)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/segmentation_models_pytorch/decoders/unet/decoder.py", line 56, in forward
#     feature_map = torch.cat([feature_map, skip_connection], dim=1)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 294.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 262.81 MiB is free. Including non-PyTorch memory, this process has 14.30 GiB memory in use. Of the allocated memory 13.78 GiB is allocated by PyTorch, and 413.52 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# [sync_outputs] 22 files consolidated under /kaggle/working/outputs, zipped to /kaggle/working/segmentation_sweep_results.zip

# %%
# Mid tier, combo 4/4 -- CoAtNet-2 U-Net (Hybrid, ~78.0M), forniceal_palpebral (3 folds, fixed best hyperparameters)
# !python Segmentation/scripts/train_pretrained_kfold/train_kfold_hybrid_mid_coatnet2_unet_forniceal_palpebral.py
sync_outputs()
# Out:
# Using device: cuda
# Model: hybrid_mid_coatnet2_unet_forniceal_palpebral (K-fold re-training, fixed hyperparameters)
# tissue_type=forniceal_palpebral image_size=224
# learning_rate=8.200518402245828e-05 weight_decay=1.9634341572933354e-06 loss_fn=bce_dice
# n_folds=3 MAX_EPOCHS=250 EARLY_STOPPING_PATIENCE=7 BATCH_SIZE=32
# Pool (train+val, aligned): 178 patients
#
# === hybrid_mid_coatnet2_unet_forniceal_palpebral | Fold 1/3: train=118 val=60 ===
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Traceback (most recent call last):
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/train_pretrained_kfold/train_kfold_hybrid_mid_coatnet2_unet_forniceal_palpebral.py", line 24, in <module>
#     run_kfold_study(
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/train_pretrained_kfold/kfold_engine.py", line 184, in run_kfold_study
#     train_loss = train_one_epoch(model, train_loader, optimizer, criterion, DEVICE)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/trainer_engine.py", line 187, in train_one_epoch
#     logits = model(images)
#              ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/segmentation_models_pytorch/base/model.py", line 67, in forward
#     decoder_output = self.decoder(features)
#                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/segmentation_models_pytorch/decoders/unet/decoder.py", line 168, in forward
#     x = decoder_block(x, height, width, skip_connection=skip_connection)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/segmentation_models_pytorch/decoders/unet/decoder.py", line 56, in forward
#     feature_map = torch.cat([feature_map, skip_connection], dim=1)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 294.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 262.81 MiB is free. Including non-PyTorch memory, this process has 14.30 GiB memory in use. Of the allocated memory 13.78 GiB is allocated by PyTorch, and 413.52 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# [sync_outputs] 22 files consolidated under /kaggle/working/outputs, zipped to /kaggle/working/segmentation_sweep_results.zip

# %% [markdown]
# ## Done — what to download
#
# This tier's fold checkpoints (fp16), logs (`*_kfold_summary.json`, `*_kfold_folds.csv`, `*_kfold_test_per_patient.csv`), and plots are consolidated at `/kaggle/working/outputs/` and zipped to `/kaggle/working/segmentation_sweep_results.zip`, visible in this notebook version's **Output** tab once you Save Version -> Save & Run All — download the zip directly from there.
#
# A failed `!python ...` cell does **not** halt "Run All" — check each script's own printed output (or the saved `*_kfold_summary.json` files) after this finishes.

# %%
from pathlib import Path

print('Final contents of /kaggle/working/outputs:')
for f in sorted(Path('/kaggle/working/outputs').rglob('*')):
    if f.is_file():
        print(f'  {f.relative_to("/kaggle/working/outputs")}  ({f.stat().st_size / 1e6:.2f} MB)')

zip_path = Path('/kaggle/working/segmentation_sweep_results.zip')
print(f"\nZip archive: {zip_path}  ({zip_path.stat().st_size / 1e6:.2f} MB)")
# Out:
# Final contents of /kaggle/working/outputs:
#   checkpoints/best_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_fold1.pth  (91.82 MB)
#   checkpoints/best_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_fold2.pth  (91.82 MB)
#   checkpoints/best_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_fold3.pth  (91.82 MB)
#   checkpoints/best_cnn_mid_resnet101_deeplabv3plus_palpebral_fold1.pth  (91.81 MB)
#   checkpoints/best_cnn_mid_resnet101_deeplabv3plus_palpebral_fold2.pth  (91.81 MB)
#   checkpoints/best_cnn_mid_resnet101_deeplabv3plus_palpebral_fold3.pth  (91.81 MB)
#   logs/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_kfold_folds.csv  (0.00 MB)
#   logs/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_kfold_summary.json  (0.00 MB)
#   logs/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_kfold_test_per_patient.csv  (0.01 MB)
#   logs/cnn_mid_resnet101_deeplabv3plus_palpebral_kfold_folds.csv  (0.00 MB)
#   logs/cnn_mid_resnet101_deeplabv3plus_palpebral_kfold_summary.json  (0.00 MB)
#   logs/cnn_mid_resnet101_deeplabv3plus_palpebral_kfold_test_per_patient.csv  (0.01 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_fold_dice_distribution.png  (0.03 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_kfold_mean_curve.png  (0.12 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_test_by_country.png  (0.04 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_test_per_patient_dice.png  (0.04 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_test_summary.png  (0.04 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_palpebral_fold_dice_distribution.png  (0.03 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_palpebral_kfold_mean_curve.png  (0.15 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_palpebral_test_by_country.png  (0.04 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_palpebral_test_per_patient_dice.png  (0.04 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_palpebral_test_summary.png  (0.04 MB)
#
# Zip archive: /kaggle/working/segmentation_sweep_results.zip  (507.74 MB)
