# %% [markdown]
# # EYES-DEFY-ANEMIA — Segmentation Phase 2 sweep: MID tier (6 of 18 combos)
#
# One of **3 tier-specific notebooks** (Base / Mid / Strong) — see `segmentation-pretrained-sweep-base.ipynb` in this same folder for the full rationale (a real Kaggle disk-quota crash on the original combined 18-combo notebook, plus the fixes applied since: single fp16 checkpoint per model instead of up to 3 fp32 ones, and a `sync_outputs()` that no longer leaves duplicate copies behind).
#
# **This notebook trains the 3 mid-tier architectures** (ResNet101 DeepLabV3+ ~45.7M, CoAtNet-2 U-Net ~78.0M, Swin-Base + UperNet ~121.3M), each on both tissue types — 6 combos total, combo numbers 7-12 of the full 18. Run the Base notebook first if you haven't, and the Strong notebook afterward. Full roster/rationale: `Segmentation/.project_memory/04_pretrained_architecture_sweep.md`.

# %% [markdown]
# ## Setup

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# GPU: Tesla T4

# %%
# rm -rf first so a re-run within the same kernel session stays idempotent
# instead of nesting a second clone inside the first.
# !rm -rf eyes-defy-anemia
# !git clone https://github.com/manivafapour/eyes-defy-anemia.git
# %cd eyes-defy-anemia
# Out:
# Cloning into 'eyes-defy-anemia'...
# remote: Enumerating objects: 1142, done.
# remote: Counting objects: 100% (823/823), done.
# remote: Compressing objects: 100% (521/521), done.
# remote: Total 1142 (delta 410), reused 671 (delta 294), pack-reused 319 (from 1)
# Receiving objects: 100% (1142/1142), 76.62 MiB | 31.45 MiB/s, done.
# Resolving deltas: 100% (573/573), done.
# /kaggle/working/eyes-defy-anemia

# %%
# Diagnostic, not a hardcoded assumption -- Kaggle's actual dataset mount
# path does not always match its display name, and can be nested deeper
# than expected (this project has been bitten by this before, twice now:
# see classification/.project_memory/kaggle/01_kaggle_notes.md -- real
# paths have landed under /kaggle/input/datasets/<username>/<slug>/, not
# directly under /kaggle/input/<slug>/). Recurses a few levels deep so
# this is caught in one pass instead of needing to descend manually.
# Read the output below, THEN set the dataset dir variable(s) in the next cell.
import os


def print_tree(path, depth=0, max_depth=4):
    for entry in sorted(os.listdir(path)):
        full = os.path.join(path, entry)
        print("  " * depth + entry)
        if os.path.isdir(full) and depth < max_depth:
            print_tree(full, depth + 1, max_depth)


print_tree("/kaggle/input")
# Out:
# datasets
#   manivafapour21
#     aligned-raw
#       aligned_raw
#         alignment_log.csv
#         images
#         masks
#     aligned-raw-forniceal
#       aligned_raw_forniceal
#         alignment_log.csv
#         images
#         masks

# %% [markdown]
# **Before running the next cell:** attach your uploaded dataset(s) to this notebook -- either both zips together as ONE Kaggle dataset, or as TWO SEPARATE datasets (this is what actually happened the first time this notebook was run: Kaggle listed them individually in the Input panel as `aligned_raw` and `aligned_raw_forniceal`). Either way, run the listing cell above, read its REAL printed output, and set the path(s) below from that -- **not** the placeholder text left in by default, and not a guessed path based on the dataset's display name (Kaggle's actual mount path does not always match it).

# %%
# Confirmed real mount paths (project author's Kaggle account, verified via
# the print_tree() listing above on 2026-08-08 -- see
# Segmentation/.project_memory/kaggle/01_kaggle_notes.md for the full
# doubly-nested structure this came from). If you re-attach the datasets
# under a different username/slug, or Kaggle changes its mount scheme again,
# re-run the listing cell above and update these two lines from its real
# output -- don't guess.
ALIGNED_RAW_DATASET_DIR = "/kaggle/input/datasets/manivafapour21/aligned-raw"
ALIGNED_RAW_FORNICEAL_DATASET_DIR = "/kaggle/input/datasets/manivafapour21/aligned-raw-forniceal"

# %%
# Only packages actually missing from Kaggle's base image (torch/torchvision,
# opencv, pandas, PIL, scikit-learn -- and therefore scipy, its own
# dependency -- are already there; scipy is listed explicitly anyway
# below rather than silently assumed, since it is now a real, load-bearing
# dependency for HD95/Wilcoxon in segmentation_metrics.py /
# compare_models_significance.py). Deliberately NOT
# `pip install -r requirements.txt` -- that file is pinned to the local
# Windows/CUDA 13.0 build and would try to reinstall Kaggle's own correctly
# configured GPU PyTorch with an incompatible build.
# !pip install -q optuna albumentations scipy segmentation-models-pytorch timm transformers einops
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 3.3 MB/s eta 0:00:00

# %% [markdown]
# ## Data

# %%
import shutil
import zipfile
from pathlib import Path

DST_ROOT = Path("Segmentation/data/processed")


def stage_tissue_data(name: str, dataset_dir: str):
    """Copies {name}/ from the given Kaggle-attached dataset directory into
    Segmentation/data/processed/{name}/. Tries three possible layouts rather
    than assuming one, since Kaggle can present an uploaded zip differently
    depending on upload method:
      1. dataset_dir/{name}/images,masks/  -- the zip's own internal "{name}/"
         prefix preserved as-is (this is how aligned_raw.zip/
         aligned_raw_forniceal.zip were actually built -- see
         Segmentation/scripts/build_aligned_dataset{,_forniceal}.py).
      2. dataset_dir/images,masks/         -- Kaggle stripped/flattened that
         top-level folder on extraction.
      3. dataset_dir/{name}.zip            -- never auto-extracted at all,
         still sitting there as a raw zip file.
    """
    dataset_dir = Path(dataset_dir)
    dst = DST_ROOT / name
    shutil.rmtree(dst, ignore_errors=True)

    nested_dir = dataset_dir / name
    flat_zip = dataset_dir / f"{name}.zip"

    if nested_dir.is_dir():
        shutil.copytree(nested_dir, dst)
    elif (dataset_dir / "images").is_dir() and (dataset_dir / "masks").is_dir():
        shutil.copytree(dataset_dir, dst)
    elif flat_zip.is_file():
        dst.mkdir(parents=True, exist_ok=True)
        with zipfile.ZipFile(flat_zip) as zf:
            zf.extractall(DST_ROOT)  # zip's own internal paths already start with f"{name}/"
    else:
        raise FileNotFoundError(
            f"Could not find {name}/, images+masks/, or {name}.zip under {dataset_dir} -- "
            f"run the /kaggle/input listing cell above and check what's actually there."
        )

    n_images = len(list((dst / "images").glob("*.jpg")))
    n_masks = len(list((dst / "masks").glob("*.png")))
    print(f"{name}: {n_images} images, {n_masks} masks staged at {dst}")


stage_tissue_data("aligned_raw", ALIGNED_RAW_DATASET_DIR)
stage_tissue_data("aligned_raw_forniceal", ALIGNED_RAW_FORNICEAL_DATASET_DIR)
# Out:
# aligned_raw: 201 images, 201 masks staged at Segmentation/data/processed/aligned_raw
# aligned_raw_forniceal: 211 images, 211 masks staged at Segmentation/data/processed/aligned_raw_forniceal

# %%
# Combined sanity check, run BEFORE any real training:
#   1. Confirm the pip-installed heavy dependencies actually work -- a
#      dataloader-only check would NOT catch a missing/broken install here
#      (classification's own Kaggle notes: a plain dataloader check only
#      exercises dataset.py's imports, so a missing package silently
#      surfaces only much later, on the first real training script).
#   2. Confirm the 9-model registry itself imports cleanly.
#   3. Pull one real batch from BOTH tissue-type dataloaders.
import sys
from pathlib import Path

sys.path.insert(0, str(Path("Segmentation/scripts").resolve()))
sys.path.insert(0, str(Path("Segmentation").resolve()))

import segmentation_models_pytorch as smp
import timm
import transformers
import einops

print("segmentation_models_pytorch", smp.__version__)
print("timm", timm.__version__)
print("transformers", transformers.__version__)
print("einops", einops.__version__)

from models.segmentation.pretrained_registry import ARCHITECTURE_REGISTRY
print(f"\n{len(ARCHITECTURE_REGISTRY)} architectures registered:")
for name in ARCHITECTURE_REGISTRY:
    print(" ", name)

from dataset import get_dataloaders

loaders = get_dataloaders()
for key in ["aligned_seg_train", "aligned_seg_forniceal_train"]:
    images, masks = next(iter(loaders[key]))
    print(f"\n{key}: image batch {tuple(images.shape)}, mask batch {tuple(masks.shape)}, "
          f"{len(loaders[key].dataset)} patients")
# Out:
# segmentation_models_pytorch 0.5.0
# timm 1.0.26
# transformers 5.0.0
# einops 0.8.2
#
# 9 architectures registered:
#   cnn_base_efficientnet_b1_unet
#   cnn_mid_resnet101_deeplabv3plus
#   cnn_strong_convnext_large_unet
#   hybrid_base_coatnet0_unet
#   hybrid_mid_coatnet2_unet
#   hybrid_strong_transunet
#   transformer_base_segformer_b2
#   transformer_mid_swin_base_upernet
#   transformer_strong_swin_large_upernet
#
# aligned_seg_train: image batch (16, 3, 256, 256), mask batch (16, 1, 256, 256), 143 patients
#
# aligned_seg_forniceal_train: image batch (16, 3, 256, 256), mask batch (16, 1, 256, 256), 147 patients

# %% [markdown]
# ## Training

# %%
import shutil
from pathlib import Path


def sync_outputs():
    """Consolidates Segmentation/outputs/{checkpoints,logs,plots}/ into a single
    top-level /kaggle/working/outputs/ folder and re-zips it to
    /kaggle/working/segmentation_sweep_results.zip. Called after EVERY
    training cell below, not just at the end -- if the run gets cut short
    partway through the 18 combos, whatever completed so far is still
    cleanly consolidated and zipped, ready to download.

    IMPORTANT (added after a real Kaggle disk-quota crash, "Your notebook
    tried to use more disk space than is available", 20.93GB used, failed
    5h40m into a real run): each of the 18 training scripts can write up to
    3 full checkpoint files at fp32 (best-overall + one per loss function),
    and none of that is ever deleted between combos -- for the larger
    architectures (ConvNeXt-Large ~203M params, Swin-Large ~234M, etc.)
    those add up to hundreds of MB to ~1GB EACH. Originally this function
    copied Segmentation/outputs/ into /kaggle/working/outputs/ and left the
    source in place, so between the untouched source, the mirrored copy,
    and the zip made from that copy, roughly 3 copies of everything
    produced so far existed on disk simultaneously -- comfortably enough to
    blow a ~20GB quota partway through the Mid/Strong tiers. Now the
    source is deleted right after it's safely copied into
    /kaggle/working/outputs/, which becomes the single accumulating copy
    (plus the zip made from it) -- every training script recreates
    Segmentation/outputs/{checkpoints,logs,plots}/ fresh via its own
    mkdir(parents=True, exist_ok=True) on its next run, so nothing is lost
    by clearing the source here.
    """
    results_dir = Path("/kaggle/working/outputs")
    results_dir.mkdir(parents=True, exist_ok=True)
    for sub in ["checkpoints", "logs", "plots"]:
        src = Path("Segmentation/outputs") / sub
        if src.exists():
            shutil.copytree(src, results_dir / sub, dirs_exist_ok=True)
            shutil.rmtree(src)
    archive_path = shutil.make_archive("/kaggle/working/segmentation_sweep_results", "zip", root_dir=str(results_dir))
    n_files = sum(1 for f in results_dir.rglob("*") if f.is_file())
    print(f"[sync_outputs] {n_files} files consolidated under {results_dir}, zipped to {archive_path}")


sync_outputs()  # harmless no-op now (nothing produced yet), confirms the function works before training starts
# Out:
# [sync_outputs] 0 files consolidated under /kaggle/working/outputs, zipped to /kaggle/working/segmentation_sweep_results.zip

# %% [markdown]
# ### Training — Mid tier (6 combos)

# %%
# Mid tier, combo 7/18 -- ResNet101 DeepLabV3+ (CNN, ~45.7M), palpebral
# !python Segmentation/scripts/train_pretrained/train_cnn_mid_resnet101_deeplabv3plus_palpebral.py
sync_outputs()
# Out:
# Using device: cuda
# Model: cnn_mid_resnet101_deeplabv3plus_palpebral (pretrained build_model)
# Dataset: AlignedConjunctivaSegmentationDataset (tissue_type=palpebral)
# Image size: 256
# [I 2026-08-10 15:38:41,095] A new study created in memory with name: no-name-0fab5ed3-59ff-43a7-9767-d4885e13d68b
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100%|██████████████████████████████| 156/156 [00:00<00:00, 466kB/s]
# model.safetensors: 100%|█████████████████████| 179M/179M [00:03<00:00, 51.6MB/s]
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0] New best overall val_dice=0.1222 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  1/30 - train_loss=0.7661 val_loss=0.8061 val_dice=0.1222 val_iou=0.0655 val_precision=0.0655 val_recall=0.9999
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0] New best overall val_dice=0.1521 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  2/30 - train_loss=0.6689 val_loss=0.8026 val_dice=0.1521 val_iou=0.0832 val_precision=0.0833 val_recall=0.9935
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0] New best overall val_dice=0.4236 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  3/30 - train_loss=0.5918 val_loss=0.8665 val_dice=0.4236 val_iou=0.2732 val_precision=0.2755 val_recall=0.9731
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0] New best overall val_dice=0.6251 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  4/30 - train_loss=0.5304 val_loss=0.7777 val_dice=0.6251 val_iou=0.4678 val_precision=0.4808 val_recall=0.9578
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0] New best overall val_dice=0.7258 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  5/30 - train_loss=0.4875 val_loss=0.5358 val_dice=0.7258 val_iou=0.5752 val_precision=0.6010 val_recall=0.9382
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  6/30 - train_loss=0.4574 val_loss=0.4981 val_dice=0.7190 val_iou=0.5690 val_precision=0.5974 val_recall=0.9284
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0] New best overall val_dice=0.7650 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  7/30 - train_loss=0.4375 val_loss=0.4171 val_dice=0.7650 val_iou=0.6242 val_precision=0.6555 val_recall=0.9364
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  8/30 - train_loss=0.4128 val_loss=3.1646 val_dice=0.4666 val_iou=0.3348 val_precision=0.3458 val_recall=0.9673
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  9/30 - train_loss=0.3969 val_loss=0.6828 val_dice=0.6765 val_iou=0.5224 val_precision=0.5498 val_recall=0.9312
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 10/30 - train_loss=0.3767 val_loss=0.4066 val_dice=0.7368 val_iou=0.5900 val_precision=0.6107 val_recall=0.9545
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 11/30 - train_loss=0.3601 val_loss=0.4336 val_dice=0.7231 val_iou=0.5745 val_precision=0.5934 val_recall=0.9538
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 12/30 - train_loss=0.3500 val_loss=0.4397 val_dice=0.7110 val_iou=0.5607 val_precision=0.5842 val_recall=0.9447
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 13/30 - train_loss=0.3376 val_loss=0.9910 val_dice=0.6108 val_iou=0.4588 val_precision=0.4843 val_recall=0.9364
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0] New best overall val_dice=0.7804 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 14/30 - train_loss=0.3202 val_loss=0.3321 val_dice=0.7804 val_iou=0.6456 val_precision=0.6795 val_recall=0.9377
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0] New best overall val_dice=0.8176 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 15/30 - train_loss=0.3069 val_loss=0.2946 val_dice=0.8176 val_iou=0.6962 val_precision=0.7563 val_recall=0.9070
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 16/30 - train_loss=0.2981 val_loss=0.2956 val_dice=0.8025 val_iou=0.6743 val_precision=0.7229 val_recall=0.9185
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 17/30 - train_loss=0.2830 val_loss=0.2738 val_dice=0.8129 val_iou=0.6893 val_precision=0.7426 val_recall=0.9138
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 18/30 - train_loss=0.2704 val_loss=0.2655 val_dice=0.8161 val_iou=0.6935 val_precision=0.7521 val_recall=0.9081
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 19/30 - train_loss=0.2579 val_loss=0.2563 val_dice=0.8101 val_iou=0.6852 val_precision=0.7310 val_recall=0.9247
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0] New best overall val_dice=0.8186 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 20/30 - train_loss=0.2457 val_loss=0.2456 val_dice=0.8186 val_iou=0.6972 val_precision=0.7578 val_recall=0.9053
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 21/30 - train_loss=0.2346 val_loss=0.2471 val_dice=0.7904 val_iou=0.6589 val_precision=0.6896 val_recall=0.9445
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0] New best overall val_dice=0.8203 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 22/30 - train_loss=0.2257 val_loss=0.2252 val_dice=0.8203 val_iou=0.6993 val_precision=0.7723 val_recall=0.8913
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 23/30 - train_loss=0.2148 val_loss=0.2290 val_dice=0.8058 val_iou=0.6796 val_precision=0.7471 val_recall=0.8929
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 24/30 - train_loss=0.2095 val_loss=0.5057 val_dice=0.6920 val_iou=0.5392 val_precision=0.5562 val_recall=0.9586
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 25/30 - train_loss=0.2040 val_loss=0.2462 val_dice=0.8160 val_iou=0.6929 val_precision=0.7904 val_recall=0.8616
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0] New best overall val_dice=0.8234 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 26/30 - train_loss=0.1929 val_loss=0.2083 val_dice=0.8234 val_iou=0.7043 val_precision=0.7841 val_recall=0.8835
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 27/30 - train_loss=0.1846 val_loss=0.1994 val_dice=0.8218 val_iou=0.7014 val_precision=0.7831 val_recall=0.8833
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 28/30 - train_loss=0.1734 val_loss=0.1930 val_dice=0.8200 val_iou=0.6998 val_precision=0.7909 val_recall=0.8710
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0] New best overall val_dice=0.8253 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 29/30 - train_loss=0.1663 val_loss=0.1832 val_dice=0.8253 val_iou=0.7073 val_precision=0.8099 val_recall=0.8584
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0] New best overall val_dice=0.8261 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 30/30 - train_loss=0.1584 val_loss=0.1823 val_dice=0.8261 val_iou=0.7083 val_precision=0.8287 val_recall=0.8424
# [I 2026-08-10 15:41:31,155] Trial 0 finished with value: 0.826068107728605 and parameters: {'learning_rate': 0.0001329291894316216, 'weight_decay': 0.0007114476009343421, 'loss_fn': 'bce_dice'}. Best is trial 0 with value: 0.826068107728605.
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 1 | loss_fn=focal_tversky] Epoch  1/30 - train_loss=0.8273 val_loss=0.8489 val_dice=0.0862 val_iou=0.0452 val_precision=0.0452 val_recall=1.0000
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 1 | loss_fn=focal_tversky] Epoch  2/30 - train_loss=0.7678 val_loss=0.8321 val_dice=0.1843 val_iou=0.1024 val_precision=0.1025 val_recall=0.9954
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 1 | loss_fn=focal_tversky] Epoch  3/30 - train_loss=0.7352 val_loss=0.7806 val_dice=0.2163 val_iou=0.1224 val_precision=0.1225 val_recall=0.9925
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 1 | loss_fn=focal_tversky] Epoch  4/30 - train_loss=0.7128 val_loss=0.7308 val_dice=0.2342 val_iou=0.1339 val_precision=0.1341 val_recall=0.9928
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 1 | loss_fn=focal_tversky] Epo
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 22/30 - train_loss=0.0602 val_loss=0.0916 val_dice=0.7958 val_iou=0.6676 val_precision=0.6921 val_recall=0.9572
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 23/30 - train_loss=0.0618 val_loss=0.0901 val_dice=0.8163 val_iou=0.6952 val_precision=0.7479 val_recall=0.9205
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 24/30 - train_loss=0.0588 val_loss=0.1067 val_dice=0.8053 val_iou=0.6824 val_precision=0.7693 val_recall=0.8638
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 2 | loss_fn=focal_tversky] Early stopping at epoch 24 (no val_loss improvement for 5 epochs).
# [I 2026-08-10 15:46:11,432] Trial 2 finished with value: 0.8323619983814381 and parameters: {'learning_rate': 0.0006358358856676254, 'weight_decay': 0.000133112160807369, 'loss_fn': 'focal_tversky'}. Best is trial 2 with value: 0.8323619983814381.
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch  1/30 - train_loss=0.6387 val_loss=0.7030 val_dice=0.1852 val_iou=0.1066 val_precision=0.1207 val_recall=0.4232
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch  2/30 - train_loss=0.3337 val_loss=1.0000 val_dice=0.0000 val_iou=0.0000 val_precision=1.0000 val_recall=0.0000
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch  3/30 - train_loss=0.1702 val_loss=1.0000 val_dice=0.0000 val_iou=0.0000 val_precision=1.0000 val_recall=0.0000
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch  4/30 - train_loss=0.1263 val_loss=0.7173 val_dice=0.2693 val_iou=0.1701 val_precision=0.9378 val_recall=0.1719
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch  5/30 - train_loss=0.1074 val_loss=0.1212 val_dice=0.8007 val_iou=0.6726 val_precision=0.8009 val_recall=0.8143
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch  6/30 - train_loss=0.0949 val_loss=0.1017 val_dice=0.8116 val_iou=0.6867 val_precision=0.7835 val_recall=0.8562
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch  7/30 - train_loss=0.0886 val_loss=0.0875 val_dice=0.8136 val_iou=0.6909 val_precision=0.7458 val_recall=0.9101
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch  8/30 - train_loss=0.0837 val_loss=0.0871 val_dice=0.8111 val_iou=0.6869 val_precision=0.7389 val_recall=0.9149
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch  9/30 - train_loss=0.0818 val_loss=0.0933 val_dice=0.8106 val_iou=0.6865 val_precision=0.7553 val_recall=0.8886
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch 10/30 - train_loss=0.0797 val_loss=0.0827 val_dice=0.8071 val_iou=0.6811 val_precision=0.7196 val_recall=0.9353
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch 11/30 - train_loss=0.0780 val_loss=0.1055 val_dice=0.8112 val_iou=0.6881 val_precision=0.7937 val_recall=0.8447
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch 12/30 - train_loss=0.0801 val_loss=0.0956 val_dice=0.7945 val_iou=0.6644 val_precision=0.7134 val_recall=0.9154
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch 13/30 - train_loss=0.0761 val_loss=0.0985 val_dice=0.8178 val_iou=0.6955 val_precision=0.7964 val_recall=0.8551
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch 14/30 - train_loss=0.0720 val_loss=0.0885 val_dice=0.8009 val_iou=0.6743 val_precision=0.7151 val_recall=0.9306
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch 15/30 - train_loss=0.0690 val_loss=0.0960 val_dice=0.8151 val_iou=0.6938 val_precision=0.7793 val_recall=0.8710
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 3 | loss_fn=focal_tversky] Early stopping at epoch 15 (no val_loss improvement for 5 epochs).
# [I 2026-08-10 15:47:38,584] Trial 3 finished with value: 0.8177841151202166 and parameters: {'learning_rate': 0.00314288089084011, 'weight_decay': 4.335281794951567e-06, 'loss_fn': 'focal_tversky'}. Best is trial 2 with value: 0.8323619983814381.
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 11 | loss_fn=focal_tversky] Epoch 10/30 - train_loss=0.0781 val_loss=0.0968 val_dice=0.8157 val_iou=0.6937 val_precision=0.7659 val_recall=0.8928
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 11 | loss_fn=focal_tversky] Epoch 11/30 - train_loss=0.0773 val_loss=0.0997 val_dice=0.7762 val_iou=0.6397 val_precision=0.6628 val_recall=0.9535
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 11 | loss_fn=focal_tversky] Epoch 12/30 - train_loss=0.0752 val_loss=0.0897 val_dice=0.7958 val_iou=0.6656 val_precision=0.6978 val_recall=0.9446
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 11 | loss_fn=focal_tversky] Epoch 13/30 - train_loss=0.0734 val_loss=0.0819 val_dice=0.8230 val_iou=0.7035 val_precision=0.7556 val_recall=0.9191
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 11 | loss_fn=focal_tversky] Epoch 14/30 - train_loss=0.0669 val_loss=0.0936 val_dice=0.8214 val_iou=0.7019 val_precision=0.7825 val_recall=0.8787
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 11 | loss_fn=focal_tversky] Epoch 15/30 - train_loss=0.0659 val_loss=0.0832 val_dice=0.8160 val_iou=0.6953 val_precision=0.7358 val_recall=0.9318
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 11 | loss_fn=focal_tversky] Epoch 16/30 - train_loss=0.0650 val_loss=0.0849 val_dice=0.8030 val_iou=0.6771 val_precision=0.7099 val_recall=0.9433
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 11 | loss_fn=focal_tversky] Epoch 17/30 - train_loss=0.0633 val_loss=0.0837 val_dice=0.8094 val_iou=0.6854 val_precision=0.7234 val_recall=0.9373
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 11 | loss_fn=focal_tversky] Epoch 18/30 - train_loss=0.0618 val_loss=0.0831 val_dice=0.8104 val_iou=0.6876 val_precision=0.7255 val_recall=0.9363
# [cnn_mid_resnet101_deeplabv3plus_palpebral | Trial 11 | loss_fn=focal_tversky] Early stopping at epoch 18 (no val_loss improvement for 5 epochs).
# [I 2026-08-10 16:08:58,562] Trial 11 finished with value: 0.822973765708782 and parameters: {'learning_rate': 0.0011746614600292322, 'weight_decay': 7.155554352960923e-05, 'loss_fn': 'focal_tversky'}. Best is trial 5 with value: 0.8340299548926177.
#
# --- Optuna study complete ---
# Model: cnn_mid_resnet101_deeplabv3plus_palpebral
# Trials run: 12
# Best trial: #5
# Best validation Dice: 0.8340
# Best validation IoU:  0.7199
# Best hyperparameters:
#   learning_rate: 0.000684792009557478
#   weight_decay: 2.62108787826544e-06
#   loss_fn: focal_tversky
#
# --- Measuring architecture properties (params, inference latency) ---
# Parameters: 45,669,713
# Inference latency (batch_size=1, 256x256): 15.52 ms
#
# --- Final test-set evaluation (best_cnn_mid_resnet101_deeplabv3plus_palpebral.pth) ---
# Overall test Dice=0.8519 IoU=0.7490 Precision=0.8405 Recall=0.8745 HD95=11.91px (undefined for 0/31 patients)
#            dice     iou  precision  recall     hd95
# country
# India    0.8548  0.7512     0.8124  0.9065   9.1623
# Italy    0.8499  0.7475     0.8608  0.8514  13.9020
#
# --- Per-loss-function comparison ---
#                 count      mean       max
# params_loss_fn
# bce_dice            5  0.799034  0.831524
# focal_tversky       7  0.800352  0.834030
#
# Saved per-trial metrics to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/cnn_mid_resnet101_deeplabv3plus_palpebral_trials.csv
# Saved best-trial summary to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/cnn_mid_resnet101_deeplabv3plus_palpebral_study_summary.json
# Saved per-patient test-set metrics to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/cnn_mid_resnet101_deeplabv3plus_palpebral_test_per_patient.csv
# Saved 6 plots to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/plots:
#   cnn_mid_resnet101_deeplabv3plus_palpebral_training_curves.png
#   cnn_mid_resnet101_deeplabv3plus_palpebral_dice_iou_curve.png
#   cnn_mid_resnet101_deeplabv3plus_palpebral_loss_fn_comparison.png
#   cnn_mid_resnet101_deeplabv3plus_palpebral_test_summary.png
#   cnn_mid_resnet101_deeplabv3plus_palpebral_test_by_country.png
#   cnn_mid_resnet101_deeplabv3plus_palpebral_test_per_patient_dice.png
# [sync_outputs] 10 files consolidated under /kaggle/working/outputs, zipped to /kaggle/working/segmentation_sweep_results.zip

# %%
# Mid tier, combo 8/18 -- ResNet101 DeepLabV3+ (CNN, ~45.7M), forniceal_palpebral
# !python Segmentation/scripts/train_pretrained/train_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral.py
sync_outputs()
# Out:
# Using device: cuda
# Model: cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral (pretrained build_model)
# Dataset: AlignedConjunctivaSegmentationDataset (tissue_type=forniceal_palpebral)
# Image size: 256
# [I 2026-08-10 16:09:27,289] A new study created in memory with name: no-name-6dcb683e-92df-43df-a2f9-78c1c6efa501
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0] New best overall val_dice=0.7015 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  1/30 - train_loss=0.6530 val_loss=0.7367 val_dice=0.7015 val_iou=0.5477 val_precision=0.5626 val_recall=0.9533
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  2/30 - train_loss=0.5099 val_loss=0.6597 val_dice=0.6726 val_iou=0.5146 val_precision=0.5160 val_recall=0.9953
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0] New best overall val_dice=0.7950 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  3/30 - train_loss=0.4127 val_loss=0.5494 val_dice=0.7950 val_iou=0.6649 val_precision=0.6827 val_recall=0.9659
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0] New best overall val_dice=0.8212 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  4/30 - train_loss=0.3475 val_loss=0.4185 val_dice=0.8212 val_iou=0.7014 val_precision=0.7083 val_recall=0.9869
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0] New best overall val_dice=0.8464 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  5/30 - train_loss=0.3020 val_loss=0.3066 val_dice=0.8464 val_iou=0.7412 val_precision=0.7554 val_recall=0.9794
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0] New best overall val_dice=0.9057 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  6/30 - train_loss=0.2671 val_loss=0.2481 val_dice=0.9057 val_iou=0.8296 val_precision=0.8733 val_recall=0.9452
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  7/30 - train_loss=0.2438 val_loss=0.2070 val_dice=0.8960 val_iou=0.8158 val_precision=0.8427 val_recall=0.9660
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0] New best overall val_dice=0.9127 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  8/30 - train_loss=0.2244 val_loss=0.1889 val_dice=0.9127 val_iou=0.8417 val_precision=0.8818 val_recall=0.9513
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0] New best overall val_dice=0.9145 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  9/30 - train_loss=0.2057 val_loss=0.1776 val_dice=0.9145 val_iou=0.8445 val_precision=0.9151 val_recall=0.9199
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 10/30 - train_loss=0.1922 val_loss=0.1751 val_dice=0.9105 val_iou=0.8374 val_precision=0.9035 val_recall=0.9240
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 11/30 - train_loss=0.1816 val_loss=0.1664 val_dice=0.9125 val_iou=0.8414 val_precision=0.8962 val_recall=0.9338
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 12/30 - train_loss=0.1685 val_loss=0.1641 val_dice=0.9099 val_iou=0.8364 val_precision=0.9217 val_recall=0.9031
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 13/30 - train_loss=0.1601 val_loss=0.1532 val_dice=0.9097 val_iou=0.8361 val_precision=0.9281 val_recall=0.8958
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0] New best overall val_dice=0.9171 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 14/30 - train_loss=0.1515 val_loss=0.1418 val_dice=0.9171 val_iou=0.8482 val_precision=0.9150 val_recall=0.9236
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0] New best overall val_dice=0.9174 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 15/30 - train_loss=0.1496 val_loss=0.1398 val_dice=0.9174 val_iou=0.8489 val_precision=0.9256 val_recall=0.9136
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 16/30 - train_loss=0.1368 val_loss=0.1315 val_dice=0.9167 val_iou=0.8476 val_precision=0.9410 val_recall=0.8972
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 17/30 - train_loss=0.1284 val_loss=0.1357 val_dice=0.9101 val_iou=0.8371 val_precision=0.9576 val_recall=0.8712
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 18/30 - train_loss=0.1289 val_loss=0.1284 val_dice=0.9159 val_iou=0.8461 val_precision=0.9334 val_recall=0.9030
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 19/30 - train_loss=0.1178 val_loss=0.1285 val_dice=0.9144 val_iou=0.8444 val_precision=0.8868 val_recall=0.9488
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 20/30 - train_loss=0.1115 val_loss=0.1180 val_dice=0.9144 val_iou=0.8441 val_precision=0.9353 val_recall=0.8993
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 21/30 - train_loss=0.1063 val_loss=0.1246 val_dice=0.9032 val_iou=0.8255 val_precision=0.9660 val_recall=0.8522
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 22/30 - train_loss=0.1024 val_loss=0.1152 val_dice=0.9166 val_iou=0.8476 val_precision=0.9129 val_recall=0.9252
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 23/30 - train_loss=0.0993 val_loss=0.1108 val_dice=0.9165 val_iou=0.8473 val_precision=0.9004 val_recall=0.9380
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0] New best overall val_dice=0.9181 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral.pth (fp16)
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 24/30 - train_loss=0.0939 val_loss=0.1059 val_dice=0.9181 val_iou=0.8504 val_precision=0.9492 val_recall=0.8931
# [cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch
nn_mid_resnet101_deeplabv3plus_forniceal_palpebral
# Trials run: 12
# Best trial: #5
# Best validation Dice: 0.9251
# Best validation IoU:  0.8621
# Best hyperparameters:
#   learning_rate: 0.000684792009557478
#   weight_decay: 2.62108787826544e-06
#   loss_fn: focal_tversky
#
# --- Measuring architecture properties (params, inference latency) ---
# Parameters: 45,669,713
# Inference latency (batch_size=1, 256x256): 13.62 ms
#
# --- Final test-set evaluation (best_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral.pth) ---
# Overall test Dice=0.9224 IoU=0.8574 Precision=0.9099 Recall=0.9386 HD95=9.52px (undefined for 0/33 patients)
#            dice     iou  precision  recall     hd95
# country
# India    0.9232  0.8586     0.9130  0.9376  11.3144
# Italy    0.9218  0.8563     0.9073  0.9394   8.0285
#
# --- Per-loss-function comparison ---
#                 count      mean       max
# params_loss_fn
# bce_dice            6  0.916117  0.924982
# focal_tversky       6  0.912206  0.925057
#
# Saved per-trial metrics to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_trials.csv
# Saved best-trial summary to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_study_summary.json
# Saved per-patient test-set metrics to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_test_per_patient.csv
# Saved 6 plots to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/plots:
#   cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_training_curves.png
#   cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_dice_iou_curve.png
#   cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_loss_fn_comparison.png
#   cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_test_summary.png
#   cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_test_by_country.png
#   cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_test_per_patient_dice.png
# [sync_outputs] 20 files consolidated under /kaggle/working/outputs, zipped to /kaggle/working/segmentation_sweep_results.zip

# %%
# Mid tier, combo 9/18 -- CoAtNet-2 U-Net (Hybrid, ~78.0M), palpebral
# !python Segmentation/scripts/train_pretrained/train_hybrid_mid_coatnet2_unet_palpebral.py
sync_outputs()
# Out:
# Using device: cuda
# Model: hybrid_mid_coatnet2_unet_palpebral (pretrained build_model)
# Dataset: AlignedConjunctivaSegmentationDataset (tissue_type=palpebral)
# Image size: 224
# [I 2026-08-10 16:42:30,794] A new study created in memory with name: no-name-1eda360d-8486-4b8f-b379-e65a623cb5ba
# model.safetensors: 100%|█████████████████████| 296M/296M [00:10<00:00, 28.9MB/s]
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0] New best overall val_dice=0.2078 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_hybrid_mid_coatnet2_unet_palpebral.pth (fp16)
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  1/30 - train_loss=0.7563 val_loss=0.7791 val_dice=0.2078 val_iou=0.1172 val_precision=0.1176 val_recall=0.9747
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0] New best overall val_dice=0.3668 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_hybrid_mid_coatnet2_unet_palpebral.pth (fp16)
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  2/30 - train_loss=0.6839 val_loss=0.7008 val_dice=0.3668 val_iou=0.2283 val_precision=0.2304 val_recall=0.9730
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0] New best overall val_dice=0.5778 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_hybrid_mid_coatnet2_unet_palpebral.pth (fp16)
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  3/30 - train_loss=0.6365 val_loss=0.6229 val_dice=0.5778 val_iou=0.4104 val_precision=0.4204 val_recall=0.9511
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0] New best overall val_dice=0.7206 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_hybrid_mid_coatnet2_unet_palpebral.pth (fp16)
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  4/30 - train_loss=0.6029 val_loss=0.5865 val_dice=0.7206 val_iou=0.5677 val_precision=0.5921 val_recall=0.9380
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  5/30 - train_loss=0.5786 val_loss=0.5709 val_dice=0.7143 val_iou=0.5616 val_precision=0.5759 val_recall=0.9634
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0] New best overall val_dice=0.7316 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_hybrid_mid_coatnet2_unet_palpebral.pth (fp16)
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  6/30 - train_loss=0.5598 val_loss=0.5566 val_dice=0.7316 val_iou=0.5818 val_precision=0.5974 val_recall=0.9621
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0] New best overall val_dice=0.7642 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_hybrid_mid_coatnet2_unet_palpebral.pth (fp16)
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  7/30 - train_loss=0.5432 val_loss=0.5395 val_dice=0.7642 val_iou=0.6238 val_precision=0.6504 val_recall=0.9432
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  8/30 - train_loss=0.5284 val_loss=0.5235 val_dice=0.7576 val_iou=0.6150 val_precision=0.6297 val_recall=0.9683
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0] New best overall val_dice=0.7724 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_hybrid_mid_coatnet2_unet_palpebral.pth (fp16)
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  9/30 - train_loss=0.5148 val_loss=0.5136 val_dice=0.7724 val_iou=0.6354 val_precision=0.6580 val_recall=0.9539
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0] New best overall val_dice=0.7936 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_hybrid_mid_coatnet2_unet_palpebral.pth (fp16)
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 10/30 - train_loss=0.5021 val_loss=0.5012 val_dice=0.7936 val_iou=0.6631 val_precision=0.6982 val_recall=0.9373
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 11/30 - train_loss=0.4892 val_loss=0.4889 val_dice=0.7805 val_iou=0.6457 val_precision=0.6680 val_recall=0.9572
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0] New best overall val_dice=0.8135 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_hybrid_mid_coatnet2_unet_palpebral.pth (fp16)
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 12/30 - train_loss=0.4777 val_loss=0.4795 val_dice=0.8135 val_iou=0.6903 val_precision=0.7483 val_recall=0.9069
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0] New best overall val_dice=0.8301 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_hybrid_mid_coatnet2_unet_palpebral.pth (fp16)
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 13/30 - train_loss=0.4659 val_loss=0.4691 val_dice=0.8301 val_iou=0.7145 val_precision=0.7977 val_recall=0.8823
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 14/30 - train_loss=0.4538 val_loss=0.4551 val_dice=0.8210 val_iou=0.7004 val_precision=0.7619 val_recall=0.9048
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 15/30 - train_loss=0.4415 val_loss=0.4486 val_dice=0.8081 val_iou=0.6821 val_precision=0.7221 val_recall=0.9309
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 16/30 - train_loss=0.4292 val_loss=0.4324 val_dice=0.7993 val_iou=0.6710 val_precision=0.7019 val_recall=0.9472
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 17/30 - train_loss=0.4166 val_loss=0.4191 val_dice=0.8193 val_iou=0.6978 val_precision=0.7584 val_recall=0.9066
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 18/30 - train_loss=0.4043 val_loss=0.4114 val_dice=0.8102 val_iou=0.6857 val_precision=0.7280 val_recall=0.9321
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 19/30 - train_loss=0.3921 val_loss=0.4002 val_dice=0.8089 val_iou=0.6844 val_precision=0.7353 val_recall=0.9142
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 20/30 - train_loss=0.3804 val_loss=0.3874 val_dice=0.7870 val_iou=0.6541 val_precision=0.6816 val_recall=0.9543
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 21/30 - train_loss=0.3696 val_loss=0.3813 val_dice=0.8232 val_iou=0.7049 val_precision=0.7847 val_recall=0.8822
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 22/30 - train_loss=0.3573 val_loss=0.3673 val_dice=0.8123 val_iou=0.6892 val_precision=0.7325 val_recall=0.9295
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 23/30 - train_loss=0.3452 val_loss=0.3560 val_dice=0.8288 val_iou=0.7114 val_precision=0.7822 val_recall=0.8982
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 24/30 - train_loss=0.3325 val_loss=0.3485 val_dice=0.8001 val_iou=0.6718 val_precision=0.7149 val_recall=0.9272
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch 25/30 - train_loss=0.3213 val_loss=0.3412 val_dice=0.8001 val_iou=0.6731 val_precision=0.7204 val_recall=0.9208
# [hybrid_mid_coatnet2_unet_palpebral | Trial 0 | loss_fn=bce_dice] Epoch
palpebral | Trial 1 | loss_fn=focal_tversky] Epoch 30/30 - train_loss=0.4191 val_loss=0.4200 val_dice=0.7778 val_iou=0.6423 val_precision=0.6663 val_recall=0.9566
# [I 2026-08-10 16:52:34,346] Trial 1 finished with value: 0.7831522248409413 and parameters: {'learning_rate': 2.9380279387035334e-05, 'weight_decay': 2.9375384576328313e-06, 'loss_fn': 'focal_tversky'}. Best is trial 0 with value: 0.8301206915466873.
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch  1/30 - train_loss=0.7497 val_loss=0.6704 val_dice=0.2293 val_iou=0.1311 val_precision=0.1321 val_recall=0.9643
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch  2/30 - train_loss=0.6600 val_loss=0.5437 val_dice=0.5021 val_iou=0.3389 val_precision=0.3498 val_recall=0.9222
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch  3/30 - train_loss=0.6163 val_loss=0.6344 val_dice=0.6868 val_iou=0.5280 val_precision=0.5425 val_recall=0.9601
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch  4/30 - train_loss=0.5808 val_loss=0.5685 val_dice=0.7013 val_iou=0.5443 val_precision=0.5576 val_recall=0.9654
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch  5/30 - train_loss=0.5429 val_loss=0.5143 val_dice=0.7082 val_iou=0.5523 val_precision=0.5592 val_recall=0.9828
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch  6/30 - train_loss=0.4943 val_loss=0.4707 val_dice=0.6511 val_iou=0.4882 val_precision=0.4905 val_recall=0.9919
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch  7/30 - train_loss=0.4399 val_loss=0.4189 val_dice=0.7288 val_iou=0.5790 val_precision=0.5867 val_recall=0.9813
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch  8/30 - train_loss=0.3821 val_loss=0.5652 val_dice=0.5978 val_iou=0.4562 val_precision=0.7623 val_recall=0.5315
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch  9/30 - train_loss=0.3177 val_loss=0.2818 val_dice=0.7894 val_iou=0.6574 val_precision=0.6848 val_recall=0.9475
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 10/30 - train_loss=0.2617 val_loss=0.2306 val_dice=0.7836 val_iou=0.6503 val_precision=0.6746 val_recall=0.9516
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 11/30 - train_loss=0.2094 val_loss=0.1959 val_dice=0.8021 val_iou=0.6760 val_precision=0.7185 val_recall=0.9243
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 12/30 - train_loss=0.1750 val_loss=0.1714 val_dice=0.7579 val_iou=0.6155 val_precision=0.6309 val_recall=0.9664
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 13/30 - train_loss=0.1497 val_loss=0.1592 val_dice=0.7641 val_iou=0.6247 val_precision=0.6417 val_recall=0.9642
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 14/30 - train_loss=0.1355 val_loss=0.1349 val_dice=0.7925 val_iou=0.6628 val_precision=0.6882 val_recall=0.9525
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 15/30 - train_loss=0.1223 val_loss=0.1330 val_dice=0.7957 val_iou=0.6664 val_precision=0.6926 val_recall=0.9502
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 16/30 - train_loss=0.1081 val_loss=0.1205 val_dice=0.8000 val_iou=0.6722 val_precision=0.7026 val_recall=0.9476
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 17/30 - train_loss=0.1003 val_loss=0.1250 val_dice=0.7684 val_iou=0.6302 val_precision=0.6451 val_recall=0.9665
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 18/30 - train_loss=0.0952 val_loss=0.1049 val_dice=0.8084 val_iou=0.6841 val_precision=0.7198 val_recall=0.9372
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 19/30 - train_loss=0.0902 val_loss=0.1359 val_dice=0.8023 val_iou=0.6818 val_precision=0.7682 val_recall=0.8583
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 20/30 - train_loss=0.0926 val_loss=0.1080 val_dice=0.8111 val_iou=0.6887 val_precision=0.7417 val_recall=0.9106
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 21/30 - train_loss=0.0844 val_loss=0.1006 val_dice=0.8215 val_iou=0.7017 val_precision=0.7567 val_recall=0.9133
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 22/30 - train_loss=0.0786 val_loss=0.1058 val_dice=0.7792 val_iou=0.6441 val_precision=0.6651 val_recall=0.9578
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 23/30 - train_loss=0.0770 val_loss=0.1088 val_dice=0.8139 val_iou=0.6928 val_precision=0.7614 val_recall=0.8892
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2] New best overall val_dice=0.8317 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_hybrid_mid_coatnet2_unet_palpebral.pth (fp16)
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 24/30 - train_loss=0.0704 val_loss=0.0928 val_dice=0.8317 val_iou=0.7160 val_precision=0.7784 val_recall=0.9057
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 25/30 - train_loss=0.0680 val_loss=0.0911 val_dice=0.8244 val_iou=0.7064 val_precision=0.7600 val_recall=0.9172
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 26/30 - train_loss=0.0665 val_loss=0.0949 val_dice=0.8053 val_iou=0.6786 val_precision=0.7191 val_recall=0.9298
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 27/30 - train_loss=0.0648 val_loss=0.1080 val_dice=0.7801 val_iou=0.6465 val_precision=0.6781 val_recall=0.9354
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 28/30 - train_loss=0.0672 val_loss=0.1065 val_dice=0.7743 val_iou=0.6388 val_precision=0.6718 val_recall=0.9421
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 29/30 - train_loss=0.0643 val_loss=0.0887 val_dice=0.8202 val_iou=0.6992 val_precision=0.7500 val_recall=0.9199
# [hybrid_mid_coatnet2_unet_palpebral | Trial 2 | loss_fn=focal_tversky] Epoch 30/30 - train_loss=0.0645 val_loss=0.0917 val_dice=0.7960 val_iou=0.6670 val_precision=0.6920 val_recall=0.9554
# [I 2026-08-10 16:57:28,881] Trial 2 finished with value: 0.8316578467686971 and parameters: {'learning_rate': 0.0006358358856676254, 'weight_decay': 0.000133112160807369, 'loss_fn': 'focal_tversky'}. Best is trial 2 with value: 0.8316578467686971.
# [hybrid_mid_coatnet2_unet_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch  1/30 - train_loss=0.7453 val_loss=0.8347 val_dice=0.0806 val_iou=0.0421 val_precision=0.0421 val_recall=0.9924
# [hybrid_mid_coatnet2_unet_palpebral | Trial 3 | loss_fn=focal_tversky] Epo
palpebral | Trial 3 | loss_fn=focal_tversky] Epoch 19/30 - train_loss=0.0827 val_loss=0.0943 val_dice=0.8025 val_iou=0.6764 val_precision=0.7379 val_recall=0.8961
# [hybrid_mid_coatnet2_unet_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch 20/30 - train_loss=0.0764 val_loss=0.1061 val_dice=0.8061 val_iou=0.6811 val_precision=0.7827 val_recall=0.8460
# [hybrid_mid_coatnet2_unet_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch 21/30 - train_loss=0.0776 val_loss=0.0986 val_dice=0.7653 val_iou=0.6253 val_precision=0.6478 val_recall=0.9523
# [hybrid_mid_coatnet2_unet_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch 22/30 - train_loss=0.0736 val_loss=0.0957 val_dice=0.7924 val_iou=0.6614 val_precision=0.7142 val_recall=0.9085
# [hybrid_mid_coatnet2_unet_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch 23/30 - train_loss=0.0737 val_loss=0.1011 val_dice=0.8002 val_iou=0.6737 val_precision=0.7475 val_recall=0.8750
# [hybrid_mid_coatnet2_unet_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch 24/30 - train_loss=0.0753 val_loss=0.0894 val_dice=0.7935 val_iou=0.6629 val_precision=0.7023 val_recall=0.9282
# [hybrid_mid_coatnet2_unet_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch 25/30 - train_loss=0.0701 val_loss=0.0912 val_dice=0.7858 val_iou=0.6523 val_precision=0.6862 val_recall=0.9377
# [hybrid_mid_coatnet2_unet_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch 26/30 - train_loss=0.0684 val_loss=0.1027 val_dice=0.7605 val_iou=0.6206 val_precision=0.6457 val_recall=0.9507
# [hybrid_mid_coatnet2_unet_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch 27/30 - train_loss=0.0755 val_loss=0.0873 val_dice=0.7940 val_iou=0.6645 val_precision=0.6966 val_recall=0.9394
# [hybrid_mid_coatnet2_unet_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch 28/30 - train_loss=0.0738 val_loss=0.0951 val_dice=0.7900 val_iou=0.6585 val_precision=0.7072 val_recall=0.9158
# [hybrid_mid_coatnet2_unet_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch 29/30 - train_loss=0.0757 val_loss=0.0954 val_dice=0.8027 val_iou=0.6750 val_precision=0.7448 val_recall=0.8895
# [hybrid_mid_coatnet2_unet_palpebral | Trial 3 | loss_fn=focal_tversky] Epoch 30/30 - train_loss=0.0721 val_loss=0.0916 val_dice=0.7957 val_iou=0.6669 val_precision=0.7124 val_recall=0.9165
# [I 2026-08-10 17:02:21,762] Trial 3 finished with value: 0.8089269465870328 and parameters: {'learning_rate': 0.00314288089084011, 'weight_decay': 4.335281794951567e-06, 'loss_fn': 'focal_tversky'}. Best is trial 2 with value: 0.8316578467686971.
# [hybrid_mid_coatnet2_unet_palpebral | Trial 4 | loss_fn=bce_dice] Epoch  1/30 - train_loss=0.9515 val_loss=0.8701 val_dice=0.1026 val_iou=0.0543 val_precision=0.0543 val_recall=0.9931
# [hybrid_mid_coatnet2_unet_palpebral | Trial 4 | loss_fn=bce_dice] Epoch  2/30 - train_loss=0.8304 val_loss=0.8364 val_dice=0.1309 val_iou=0.0703 val_precision=0.0704 val_recall=0.9856
# [hybrid_mid_coatnet2_unet_palpebral | Trial 4 | loss_fn=bce_dice] Epoch  3/30 - train_loss=0.7808 val_loss=0.7900 val_dice=0.1994 val_iou=0.1114 val_precision=0.1117 val_recall=0.9809
# [hybrid_mid_coatnet2_unet_palpebral | Trial 4 | loss_fn=bce_dice] Epoch  4/30 - train_loss=0.7437 val_loss=0.7607 val_dice=0.2961 val_iou=0.1753 val_precision=0.1761 val_recall=0.9784
palpebral | Trial 4 | loss_fn=bce_dice] Epoch 21/30 - train_loss=0.5336 val_loss=0.5480 val_dice=0.7717 val_iou=0.6318 val_precision=0.6815 val_recall=0.9063
# [hybrid_mid_coatnet2_unet_palpebral | Trial 4 | loss_fn=bce_dice] Epoch 22/30 - train_loss=0.5268 val_loss=0.5393 val_dice=0.7826 val_iou=0.6469 val_precision=0.7419 val_recall=0.8415
# [hybrid_mid_coatnet2_unet_palpebral | Trial 4 | loss_fn=bce_dice] Epoch 23/30 - train_loss=0.5209 val_loss=0.5337 val_dice=0.7776 val_iou=0.6399 val_precision=0.6859 val_recall=0.9152
# [hybrid_mid_coatnet2_unet_palpebral | Trial 4 | loss_fn=bce_dice] Epoch 24/30 - train_loss=0.5131 val_loss=0.5377 val_dice=0.7569 val_iou=0.6128 val_precision=0.6354 val_recall=0.9564
# [hybrid_mid_coatnet2_unet_palpebral | Trial 4 | loss_fn=bce_dice] Epoch 25/30 - train_loss=0.5056 val_loss=0.5144 val_dice=0.8124 val_iou=0.6878 val_precision=0.7418 val_recall=0.9130
# [hybrid_mid_coatnet2_unet_palpebral | Trial 4 | loss_fn=bce_dice] Epoch 26/30 - train_loss=0.4992 val_loss=0.5157 val_dice=0.8103 val_iou=0.6844 val_precision=0.7334 val_recall=0.9207
# [hybrid_mid_coatnet2_unet_palpebral | Trial 4 | loss_fn=bce_dice] Epoch 27/30 - train_loss=0.4932 val_loss=0.5103 val_dice=0.8086 val_iou=0.6820 val_precision=0.7197 val_recall=0.9382
# [hybrid_mid_coatnet2_unet_palpebral | Trial 4 | loss_fn=bce_dice] Epoch 28/30 - train_loss=0.4861 val_loss=0.5059 val_dice=0.8081 val_iou=0.6817 val_precision=0.7162 val_recall=0.9414
# [hybrid_mid_coatnet2_unet_palpebral | Trial 4 | loss_fn=bce_dice] Epoch 29/30 - train_loss=0.4808 val_loss=0.4914 val_dice=0.8271 val_iou=0.7083 val_precision=0.7667 val_recall=0.9119
# [hybrid_mid_coatnet2_unet_palpebral | Trial 4 | loss_fn=bce_dice] Epoch 30/30 - train_loss=0.4747 val_loss=0.4859 val_dice=0.8227 val_iou=0.7024 val_precision=0.7551 val_recall=0.9188
# [I 2026-08-10 17:07:16,721] Trial 4 finished with value: 0.8271384128817806 and parameters: {'learning_rate': 8.17949947521167e-05, 'weight_decay': 3.752055855124284e-05, 'loss_fn': 'bce_dice'}. Best is trial 2 with value: 0.8316578467686971.
# [hybrid_mid_coatnet2_unet_palpebral | Trial 5 | loss_fn=focal_tversky] Epoch  1/30 - train_loss=0.7377 val_loss=0.9075 val_dice=0.0237 val_iou=0.0121 val_precision=0.0237 val_recall=0.0251
# [hybrid_mid_coatnet2_unet_palpebral | Trial 5 | loss_fn=focal_tversky] Epoch  2/30 - train_loss=0.6457 val_loss=0.9932 val_dice=0.0000 val_iou=0.0000 val_precision=0.0000 val_recall=0.0000
# [hybrid_mid_coatnet2_unet_palpebral | Trial 5 | loss_fn=focal_tversky] Epoch  3/30 - train_loss=0.5692 val_loss=0.5697 val_dice=0.6612 val_iou=0.4981 val_precision=0.5093 val_recall=0.9659
# [hybrid_mid_coatnet2_unet_palpebral | Trial 5 | loss_fn=focal_tversky] Epoch  4/30 - train_loss=0.4817 val_loss=0.4862 val_dice=0.6831 val_iou=0.5250 val_precision=0.5307 val_recall=0.9838
# [hybrid_mid_coatnet2_unet_palpebral | Trial 5 | loss_fn=focal_tversky] Epoch  5/30 - train_loss=0.3888 val_loss=0.3649 val_dice=0.7720 val_iou=0.6342 val_precision=0.6584 val_recall=0.9498
# [hybrid_mid_coatnet2_unet_palpebral | Trial 5 | loss_fn=focal_tversky] Epoch  6/30 - train_loss=0.3025 val_loss=0.3009 val_dice=0.7888 val_iou=0.6550 val_precision=0.7385 val_recall=0.8593
# [hybrid_mid_coatnet2_unet_palpebral | Trial 5 | loss_fn=focal_tversky] Epo
palpebral | Trial 5 | loss_fn=focal_tversky] Epoch 25/30 - train_loss=0.0613 val_loss=0.0856 val_dice=0.8051 val_iou=0.6794 val_precision=0.7086 val_recall=0.9493
# [hybrid_mid_coatnet2_unet_palpebral | Trial 5 | loss_fn=focal_tversky] Epoch 26/30 - train_loss=0.0611 val_loss=0.1109 val_dice=0.7605 val_iou=0.6275 val_precision=0.6487 val_recall=0.9572
# [hybrid_mid_coatnet2_unet_palpebral | Trial 5 | loss_fn=focal_tversky] Epoch 27/30 - train_loss=0.0604 val_loss=0.0933 val_dice=0.8216 val_iou=0.7011 val_precision=0.7772 val_recall=0.8923
# [hybrid_mid_coatnet2_unet_palpebral | Trial 5 | loss_fn=focal_tversky] Epoch 28/30 - train_loss=0.0577 val_loss=0.0852 val_dice=0.8228 val_iou=0.7027 val_precision=0.7613 val_recall=0.9115
# [hybrid_mid_coatnet2_unet_palpebral | Trial 5] New best overall val_dice=0.8322 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_hybrid_mid_coatnet2_unet_palpebral.pth (fp16)
# [hybrid_mid_coatnet2_unet_palpebral | Trial 5 | loss_fn=focal_tversky] Epoch 29/30 - train_loss=0.0548 val_loss=0.1007 val_dice=0.8322 val_iou=0.7172 val_precision=0.8349 val_recall=0.8437
# [hybrid_mid_coatnet2_unet_palpebral | Trial 5 | loss_fn=focal_tversky] Epoch 30/30 - train_loss=0.0537 val_loss=0.0865 val_dice=0.8060 val_iou=0.6803 val_precision=0.7185 val_recall=0.9377
# [I 2026-08-10 17:12:10,275] Trial 5 finished with value: 0.8322458973637333 and parameters: {'learning_rate': 0.000684792009557478, 'weight_decay': 2.62108787826544e-06, 'loss_fn': 'focal_tversky'}. Best is trial 5 with value: 0.8322458973637333.
# [hybrid_mid_coatnet2_unet_palpebral | Trial 6 | loss_fn=focal_tversky] Epoch  1/30 - train_loss=0.7123 val_loss=0.6538 val_dice=0.3287 val_iou=0.1999 val_precision=0.2005 val_recall=0.9899
# [hybrid_mid_coatnet2_unet_palpebral | Trial 6 | loss_fn=focal_tversky] Epoch  2/30 - train_loss=0.6111 val_loss=0.6003 val_dice=0.4600 val_iou=0.3035 val_precision=0.3039 val_recall=0.9974
# [hybrid_mid_coatnet2_unet_palpebral | Trial 6 | loss_fn=focal_tversky] Epoch  3/30 - train_loss=0.5520 val_loss=0.5316 val_dice=0.6573 val_iou=0.4954 val_precision=0.5070 val_recall=0.9615
# [hybrid_mid_coatnet2_unet_palpebral | Trial 6 | loss_fn=focal_tversky] Epoch  4/30 - train_loss=0.5038 val_loss=0.4726 val_dice=0.7031 val_iou=0.5485 val_precision=0.5564 val_recall=0.9795
# [hybrid_mid_coatnet2_unet_palpebral | Trial 6 | loss_fn=focal_tversky] Epoch  5/30 - train_loss=0.4605 val_loss=0.4393 val_dice=0.7067 val_iou=0.5532 val_precision=0.5602 val_recall=0.9810
# [hybrid_mid_coatnet2_unet_palpebral | Trial 6 | loss_fn=focal_tversky] Epoch  6/30 - train_loss=0.4225 val_loss=0.4002 val_dice=0.7440 val_iou=0.5971 val_precision=0.6121 val_recall=0.9662
# [hybrid_mid_coatnet2_unet_palpebral | Trial 6 | loss_fn=focal_tversky] Epoch  7/30 - train_loss=0.3895 val_loss=0.3733 val_dice=0.7539 val_iou=0.6096 val_precision=0.6251 val_recall=0.9679
# [hybrid_mid_coatnet2_unet_palpebral | Trial 6 | loss_fn=focal_tversky] Epoch  8/30 - train_loss=0.3545 val_loss=0.3541 val_dice=0.8044 val_iou=0.6779 val_precision=0.7215 val_recall=0.9266
# [hybrid_mid_coatnet2_unet_palpebral | Trial 6 | loss_fn=focal_tversky] Epoch  9/30 - train_loss=0.3278 val_loss=0.3181 val_dice=0.7735 val_iou=0.6376 val_precision=0.6569 val_recall=0.9610
# [hybrid_mid_coatnet2_unet_palpebral | Trial 6 | loss_fn=focal_tversky] Epoch
palpebral | Trial 6 | loss_fn=focal_tversky] Epoch 28/30 - train_loss=0.0832 val_loss=0.1303 val_dice=0.8004 val_iou=0.6718 val_precision=0.7095 val_recall=0.9395
# [hybrid_mid_coatnet2_unet_palpebral | Trial 6 | loss_fn=focal_tversky] Epoch 29/30 - train_loss=0.0810 val_loss=0.1174 val_dice=0.8049 val_iou=0.6781 val_precision=0.7084 val_recall=0.9487
# [hybrid_mid_coatnet2_unet_palpebral | Trial 6 | loss_fn=focal_tversky] Epoch 30/30 - train_loss=0.0755 val_loss=0.1188 val_dice=0.8032 val_iou=0.6744 val_precision=0.7163 val_recall=0.9311
# [I 2026-08-10 17:17:04,039] Trial 6 finished with value: 0.8288482162687514 and parameters: {'learning_rate': 0.00023345864076016249, 'weight_decay': 0.0002267398652378039, 'loss_fn': 'focal_tversky'}. Best is trial 5 with value: 0.8322458973637333.
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch  1/30 - train_loss=0.7234 val_loss=1.2256 val_dice=0.0964 val_iou=0.0508 val_precision=0.0509 val_recall=0.9865
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch  2/30 - train_loss=0.5965 val_loss=0.5988 val_dice=0.2442 val_iou=0.1588 val_precision=0.4110 val_recall=0.1848
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch  3/30 - train_loss=0.5330 val_loss=0.5494 val_dice=0.7203 val_iou=0.5702 val_precision=0.5922 val_recall=0.9398
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch  4/30 - train_loss=0.4840 val_loss=0.4525 val_dice=0.7915 val_iou=0.6595 val_precision=0.7112 val_recall=0.9090
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch  5/30 - train_loss=0.4348 val_loss=0.4141 val_dice=0.7578 val_iou=0.6158 val_precision=0.6437 val_recall=0.9399
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch  6/30 - train_loss=0.3892 val_loss=0.3673 val_dice=0.7820 val_iou=0.6485 val_precision=0.6831 val_recall=0.9316
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch  7/30 - train_loss=0.3398 val_loss=0.3295 val_dice=0.7735 val_iou=0.6370 val_precision=0.6700 val_recall=0.9351
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch  8/30 - train_loss=0.2945 val_loss=0.2760 val_dice=0.8099 val_iou=0.6851 val_precision=0.7377 val_recall=0.9138
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch  9/30 - train_loss=0.2505 val_loss=0.2418 val_dice=0.8169 val_iou=0.6947 val_precision=0.7787 val_recall=0.8748
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch 10/30 - train_loss=0.2180 val_loss=0.2147 val_dice=0.8179 val_iou=0.6975 val_precision=0.7939 val_recall=0.8601
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch 11/30 - train_loss=0.1934 val_loss=0.1881 val_dice=0.8241 val_iou=0.7052 val_precision=0.7851 val_recall=0.8839
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch 12/30 - train_loss=0.1695 val_loss=0.1855 val_dice=0.8009 val_iou=0.6752 val_precision=0.7398 val_recall=0.8894
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch 13/30 - train_loss=0.1551 val_loss=0.1765 val_dice=0.8046 val_iou=0.6806 val_precision=0.8347 val_recall=0.7914
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch 14/30 - train_loss=0.1481 val_loss=0.1622 val_dice=0.8100 val_iou=0.6860 val_precision=0.8042 val_recall=0.8301
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch 15/30 - train_loss=0.1347 val_loss=0.1572 val_dice=0.8134 val_iou=0.6899 val_precision=0.7778 val_recall=0.8699
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch 16/30 - train_loss=0.1273 val_loss=0.1536 val_dice=0.8081 val_iou=0.6822 val_precision=0.7510 val_recall=0.8899
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch 17/30 - train_loss=0.1232 val_loss=0.1768 val_dice=0.7745 val_iou=0.6410 val_precision=0.6818 val_recall=0.9191
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch 18/30 - train_loss=0.1192 val_loss=0.1663 val_dice=0.7843 val_iou=0.6527 val_precision=0.7566 val_recall=0.8301
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch 19/30 - train_loss=0.1136 val_loss=0.1492 val_dice=0.8009 val_iou=0.6749 val_precision=0.7730 val_recall=0.8485
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch 20/30 - train_loss=0.1097 val_loss=0.1333 val_dice=0.8243 val_iou=0.7055 val_precision=0.8209 val_recall=0.8461
# [hybrid_mid_coatnet2_unet_palpebral | Trial 7 | loss_fn=bce_dice] Epoch 21/30 - train_loss=0.1014 val_loss=0.1296 val_dice=0.8287 val_iou=0.7119 val_precision=0.8077 val_recall=0.8677
# ...
# [hybrid_mid_coatnet2_unet_palpebral | Trial 9 | loss_fn=bce_dice] Epoch  8/30 - train_loss=0.5055 val_loss=0.5027 val_dice=0.8011 val_iou=0.6726 val_precision=0.7183 val_recall=0.9253
# [hybrid_mid_coatnet2_unet_palpebral | Trial 9 | loss_fn=bce_dice] Epoch  9/30 - train_loss=0.4930 val_loss=0.4993 val_dice=0.7729 val_iou=0.6361 val_precision=0.6578 val_recall=0.9574
# [hybrid_mid_coatnet2_unet_palpebral | Trial 9 | loss_fn=bce_dice] Epoch 10/30 - train_loss=0.4810 val_loss=0.4881 val_dice=0.7776 val_iou=0.6421 val_precision=0.6724 val_recall=0.9441
# [hybrid_mid_coatnet2_unet_palpebral | Trial 9 | loss_fn=bce_dice] Epoch
palpebral | Trial 9 | loss_fn=bce_dice] Epoch 28/30 - train_loss=0.3257 val_loss=0.3579 val_dice=0.8119 val_iou=0.6887 val_precision=0.7324 val_recall=0.9299
# [hybrid_mid_coatnet2_unet_palpebral | Trial 9 | loss_fn=bce_dice] Epoch 29/30 - train_loss=0.3182 val_loss=0.3420 val_dice=0.8321 val_iou=0.7158 val_precision=0.7922 val_recall=0.8903
# [hybrid_mid_coatnet2_unet_palpebral | Trial 9 | loss_fn=bce_dice] Epoch 30/30 - train_loss=0.3117 val_loss=0.3408 val_dice=0.8243 val_iou=0.7048 val_precision=0.7594 val_recall=0.9179
# [I 2026-08-10 17:31:06,334] Trial 9 finished with value: 0.8320689797401428 and parameters: {'learning_rate': 8.200518402245828e-05, 'weight_decay': 1.9634341572933354e-06, 'loss_fn': 'bce_dice'}. Best is trial 5 with value: 0.8322458973637333.
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch  1/30 - train_loss=0.8030 val_loss=0.9084 val_dice=0.0457 val_iou=0.0235 val_precision=0.0246 val_recall=0.3449
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch  2/30 - train_loss=0.5670 val_loss=0.8369 val_dice=0.0792 val_iou=0.0414 val_precision=0.0414 val_recall=1.0000
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch  3/30 - train_loss=0.3053 val_loss=0.9121 val_dice=0.0143 val_iou=0.0073 val_precision=0.0104 val_recall=0.0234
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch  4/30 - train_loss=0.1952 val_loss=0.8018 val_dice=0.1012 val_iou=0.0537 val_precision=0.0555 val_recall=0.6111
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch  5/30 - train_loss=0.1794 val_loss=0.5675 val_dice=0.2426 val_iou=0.1410 val_precision=0.1516 val_recall=0.6489
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch  6/30 - train_loss=0.1373 val_loss=0.3184 val_dice=0.6275 val_iou=0.4737 val_precision=0.5199 val_recall=0.8701
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch  7/30 - train_loss=0.1286 val_loss=0.2114 val_dice=0.7096 val_iou=0.5551 val_precision=0.7659 val_recall=0.6804
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch  8/30 - train_loss=0.1201 val_loss=0.1312 val_dice=0.7670 val_iou=0.6293 val_precision=0.7296 val_recall=0.8293
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch  9/30 - train_loss=0.1224 val_loss=0.2032 val_dice=0.7378 val_iou=0.5901 val_precision=0.8235 val_recall=0.6909
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 10/30 - train_loss=0.1293 val_loss=0.1885 val_dice=0.7461 val_iou=0.5999 val_precision=0.8379 val_recall=0.6838
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 11/30 - train_loss=0.1182 val_loss=0.1223 val_dice=0.7443 val_iou=0.6024 val_precision=0.6389 val_recall=0.9091
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 12/30 - train_loss=0.1067 val_loss=0.1355 val_dice=0.7038 val_iou=0.5506 val_precision=0.5696 val_recall=0.9493
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 13/30 - train_loss=0.1058 val_loss=0.1090 val_dice=0.7790 val_iou=0.6444 val_precision=0.7102 val_recall=0.8820
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 14/30 - train_loss=0.1007 val_loss=0.1776 val_dice=0.7496 val_iou=0.6144 val_precision=0.8080 val_recall=0.7276
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 15/30 - train_loss=0.0959 val_loss=0.1049 val_dice=0.7806 val_iou=0.6469 val_precision=0.7033 val_recall=0.8932
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 16/30 - train_loss=0.0928 val_loss=0.1108 val_dice=0.7767 val_iou=0.6436 val_precision=0.7038 val_recall=0.8819
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 17/30 - train_loss=0.0918 val_loss=0.1008 val_dice=0.7910 val_iou=0.6600 val_precision=0.7257 val_recall=0.8871
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 18/30 - train_loss=0.0919 val_loss=0.1017 val_dice=0.7877 val_iou=0.6563 val_precision=0.7183 val_recall=0.8915
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 19/30 - train_loss=0.0877 val_loss=0.0969 val_dice=0.7825 val_iou=0.6475 val_precision=0.6908 val_recall=0.9177
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 20/30 - train_loss=0.0863 val_loss=0.0912 val_dice=0.7822 val_iou=0.6477 val_precision=0.6776 val_recall=0.9424
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 21/30 - train_loss=0.0868 val_loss=0.0994 val_dice=0.7710 val_iou=0.6340 val_precision=0.6648 val_recall=0.9351
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 22/30 - train_loss=0.0839 val_loss=0.1181 val_dice=0.8001 val_iou=0.6735 val_precision=0.8004 val_recall=0.8153
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 23/30 - train_loss=0.0862 val_loss=0.1084 val_dice=0.8045 val_iou=0.6779 val_precision=0.7893 val_recall=0.8355
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 24/30 - train_loss=0.0876 val_loss=0.0977 val_dice=0.7629 val_iou=0.6219 val_precision=0.6421 val_recall=0.9572
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 25/30 - train_loss=0.0862 val_loss=0.0894 val_dice=0.8021 val_iou=0.6746 val_precision=0.7272 val_recall=0.9081
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 26/30 - train_loss=0.0809 val_loss=0.1062 val_dice=0.8086 val_iou=0.6825 val_precision=0.7967 val_recall=0.8348
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 27/30 - train_loss=0.0818 val_loss=0.1051 val_dice=0.7516 val_iou=0.6080 val_precision=0.6281 val_recall=0.9533
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 28/30 - train_loss=0.0785 val_loss=0.1050 val_dice=0.7528 val_iou=0.6091 val_precision=0.6303 val_recall=0.9509
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 29/30 - train_loss=0.0853 val_loss=0.0862 val_dice=0.8017 val_iou=0.6739 val_precision=0.7182 val_recall=0.9208
# [hybrid_mid_coatnet2_unet_palpebral | Trial 10 | loss_fn=focal_tversky] Epoch 30/30 - train_loss=0.0787 val_loss=0.1012 val_dice=0.8050 val_iou=0.6775 val_precision=0.7711 val_recall=0.8584
# [I 2026-08-10 17:35:57,868] Trial 10 finished with value: 0.8086248834927877 and parameters: {'learning_rate': 0.007765857606669492, 'weight_decay': 1.2336245991553763e-05, 'loss_fn': 'focal_tversky'}. Best is trial 5 with value: 0.8322458973637333.
# [hybrid_mid_coatnet2_unet_palpebral | Trial 11 | loss_fn=bce_dice] Epoch  1/30 - train_loss=0.6693 val_loss=57.1455 val_dice=0.0886 val_iou=0.0465 val_precision=0.0465 val_recall=0.9981
# [hybrid_mid_coatnet2_unet_palpebral | Trial 11 | loss_fn=bce_dice] Epoch  2/30 - train_loss=0.4468 val_loss=1.1125 val_dice=0.1516 val_iou=0.0828 val_precision=0.0829 val_recall=0.9754
# [hybrid_mid_coatnet2_unet_palpebral | Trial 11 | loss_fn=bce_dice] Epoch  3/30 - train_loss=0.3365 val_loss=0.4011 val_dice=0.7470 val_iou=0.6030 val_precision=0.7487 val_recall=0.7650
# [hybrid_mid_coatnet2_unet_palpebral | Trial 11 | loss_fn=bce_dice] Epoch  4/30 - train_loss=0.2477 val_loss=0.2754 val_dice=0.7574 val_iou=0.6141 val_precision=0.6361 val_recall=0.9526
# [hybrid_mid_coatnet2_unet_palpebral | Trial 11 | loss_fn=bce_dice] Epoch  5/30 - train_loss=0.1901 val_loss=0.1978 val_dice=0.7957 val_iou=0.6673 val_precision=0.7829 val_recall=0.8247
# [hybrid_mid_coatnet2_unet_palpebral | Trial 11 | loss_fn=bce_dice] Epoch  6/30 - train_loss=0.1625 val_loss=0.1674 val_dice=0.7942 val_iou=0.6631 val_precision=0.7194 val_recall=0.9011
# [hybrid_mid_coatnet2_unet_palpebral | Trial 11 | loss_fn=bce_dice] Epoch  7/30 - train_loss=0.1473 val_loss=0.1933 val_dice=0.7357 val_iou=0.5927 val_precision=0.6498 val_recall=0.8640
# [hybrid_mid_coatnet2_unet_palpebral | Trial 11 | loss_fn=bce_dice] Epoch  8/30 - train_loss=0.1370 val_loss=0.1515 val_dice=0.7955 val_iou=0.6633 val_precision=0.7703 val_recall=0.8408
# [hybrid_mid_coatnet2_unet_palpebral | Trial 11 | loss_fn=bce_dice] Epoch  9/30 - train_loss=0.1228 val_loss=0.1489 val_dice=0.7932 val_iou=0.6600 val_precision=0.8227 val_recall=0.7788
# [hybrid_mid_coatnet2_unet_palpebral | Trial 11 | loss_fn=bce_dice] Epoch 10/30 - train_loss=0.1220 val_loss=0.1330 val_dice=0.8154 val_iou=0.6922 val_precision=0.8184 val_recall=0.8244
# [hybrid_mid_coatnet2_unet_palpebral | Trial 11 | loss_fn=bce_dice] Epoch 11/30 - train_loss=0.1160 val_loss=0.1561 val_dice=0.7804 val_iou=0.6485 val_precision=0.7321 val_recall=0.8515
# [hybrid_mid_coatnet2_unet_palpebral | Trial 11 | loss_fn=bce_dice] Epoch 12/30 - train_loss=0.1187 val_loss=0.1270 val_dice=0.8198 val_iou=0.6986 val_precision=0.7728 val_recall=0.8887
# [hybrid_mid_coatnet2_unet_palpebral | Trial 11 | loss_fn=bce_dice] Epoch 13/30 - train_loss=0.1121 val_loss=0.1375 val_dice=0.8032 val_iou=0.6766 val_precision=0.7953 val_recall=0.8309
# [hybrid_mid_coatnet2_unet_palpebral | Trial 11 | loss_fn=bce_dice] Epoch 14/30 - train_loss=0.1069 val_loss=0.1479 val_dice=0.7845 val_iou=0.6545 val_precision=0.8384 val_recall=0.7580
# [hybrid_mid_coatnet2_unet_palpebral | Trial 11 | loss_fn=bce_dice] Epoch 15/30 - train_loss=0.1120 val_loss=0.1433 val_dice=0.7968 val_iou=0.6669 val_precision=0.8099 val_recall=0.8103
# [hybrid_mid_coatnet2_unet_palpebral | Trial 11 | loss_fn=bce_dice] Epoch 16/30 - train_loss=0.1011 val_loss=0.1275 val_dice=0.8175 val_iou=0.6950 val_precision=0.8017 val_recall=0.8508
# [hybrid_mid_coatnet2_unet_palpebral | Trial 11 | loss_fn=bce_dice] Epoch 17/30 - train_loss=0.1048 val_loss=0.1447 val_dice=0.7941 val_iou=0.6683 val_precision=0.7468 val_recall=0.8645
# [hybrid_mid_coatnet2_unet_palpebral | Trial 11 | loss_fn=bce_dice] Early stopping at epoch 17 (no val_loss improvement for 5 epochs).
# [I 2026-08-10 17:38:44,136] Trial 11 finished with value: 0.8197500308354696 and parameters: {'learning_rate': 0.0013601770686063575, 'weight_decay': 1.090134950000262e-06, 'loss_fn': 'bce_dice'}. Best is trial 5 with value: 0.8322458973637333.
#
# --- Optuna study complete ---
# Model: hybrid_mid_coatnet2_unet_palpebral
# Trials run: 12
# Best trial: #5
# Best validation Dice: 0.8322
# Best validation IoU:  0.7172
# Best hyperparameters:
#   learning_rate: 0.000684792009557478
#   weight_decay: 2.62108787826544e-06
#   loss_fn: focal_tversky
#
# --- Measuring architecture properties (params, inference latency) ---
# Parameters: 77,965,273
# Inference latency (batch_size=1, 224x224): 22.06 ms
#
# --- Final test-set evaluation (best_hybrid_mid_coatnet2_unet_palpebral.pth) ---
# Overall test Dice=0.7988 IoU=0.6789 Precision=0.8529 Recall=0.7780 HD95=13.29px (undefined for 0/31 patients)
#            dice     iou  precision  recall     hd95
# country
# India    0.8104  0.6866     0.7987  0.8349  12.9665
# Italy    0.7905  0.6733     0.8919  0.7369  13.5285
#
# --- Per-loss-function comparison ---
#                 count      mean       max
# params_loss_fn
# bce_dice            6  0.804170  0.832069
# focal_tversky       6  0.815576  0.832246
#
# Saved per-trial metrics to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/hybrid_mid_coatnet2_unet_palpebral_trials.csv
# Saved best-trial summary to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/hybrid_mid_coatnet2_unet_palpebral_study_summary.json
# Saved per-patient test-set metrics to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/hybrid_mid_coatnet2_unet_palpebral_test_per_patient.csv
# Saved 6 plots to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/plots:
#   hybrid_mid_coatnet2_unet_palpebral_training_curves.png
#   hybrid_mid_coatnet2_unet_palpebral_dice_iou_curve.png
#   hybrid_mid_coatnet2_unet_palpebral_loss_fn_comparison.png
#   hybrid_mid_coatnet2_unet_palpebral_test_summary.png
#   hybrid_mid_coatnet2_unet_palpebral_test_by_country.png
#   hybrid_mid_coatnet2_unet_palpebral_test_per_patient_dice.png
# [sync_outputs] 30 files consolidated under /kaggle/working/outputs, zipped to /kaggle/working/segmentation_sweep_results.zip

# %%
# Mid tier, combo 10/18 -- CoAtNet-2 U-Net (Hybrid, ~78.0M), forniceal_palpebral
# !python Segmentation/scripts/train_pretrained/train_hybrid_mid_coatnet2_unet_forniceal_palpebral.py
sync_outputs()
# Out:
# Using device: cuda
# Model: hybrid_mid_coatnet2_unet_forniceal_palpebral (pretrained build_model)
# Dataset: AlignedConjunctivaSegmentationDataset (tissue_type=forniceal_palpebral)
# Image size: 224
# [I 2026-08-10 17:39:20,184] A new study created in memory with name: no-name-378fc36b-37ed-4a89-9336-b616eb846d04
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [hybrid_mid_coatnet2_unet_forniceal_palpebral | Trial 0] New best overall val_dice=0.5686 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_hybrid_mid_coatnet2_unet_forniceal_palpebral.pth (fp16)
# [hybrid_mid_coatnet2_unet_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  1/30 - train_loss=0.6351 val_loss=0.6223 val_dice=0.5686 val_iou=0.4125 val_precision=0.5173 val_recall=0.6476
# [hybrid_mid_coatnet2_unet_forniceal_palpebral | Trial 0] New best overall val_dice=0.7966 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_hybrid_mid_coatnet2_unet_forniceal_palpebral.pth (fp16)
# [hybrid_mid_coatnet2_unet_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  2/30 - train_loss=0.5129 val_loss=0.4878 val_dice=0.7966 val_iou=0.6678 val_precision=0.6890 val_recall=0.9623
# [hybrid_mid_coatnet2_unet_forniceal_palpebral | Trial 0] New best overall val_dice=0.8643 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_hybrid_mid_coatnet2_unet_forniceal_palpebral.pth (fp16)
# [hybrid_mid_coatnet2_unet_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  3/30 - train_loss=0.4538 val_loss=0.4208 val_dice=0.8643 val_iou=0.7631 val_precision=0.8759 val_recall=0.8641
# [hybrid_mid_coatnet2_unet_forniceal_palpebral | Trial 0] New best overall val_dice=0.9067 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_hybrid_mid_coatnet2_unet_forniceal_palpebral.pth (fp16)
# [hybrid_mid_coatnet2_unet_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  4/30 - train_loss=0.4152 val_loss=0.3728 val_dice=0.9067 val_iou=0.8311 val_precision=0.8831 val_recall=0.9367
# [hybrid_mid_coatnet2_unet_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  5/30 - train_loss=0.3857 val_loss=0.3612 val_dice=0.9057 val_iou=0.8294 val_precision=0.9103 val_recall=0.9062
# [hybrid_mid_coatnet2_unet_forniceal_palpebral | Trial 0] New best overall val_dice=0.9183 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_hybrid_mid_coatnet2_unet_forniceal_palpebral.pth (fp16)
# [hybrid_mid_coatnet2_unet_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  6/30 - train_loss=0.3604 val_loss=0.3265 val_dice=0.9183 val_iou=0.8512 val_precision=0.9024 val_recall=0.9407
# [hybrid_mid_coatnet2_unet_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  7/30 - train_loss=0.3387 val_loss=0.3465 val_dice=0.8235 val_iou=0.7078 val_precision=0.7127 val_recall=0.9931
# [hybrid_mid_coatnet2_unet_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  8/30 - train_loss=0.3202 val_loss=0.2957 val_dice=0.9137 val_iou=0.8448 val_precision=0.8804 val_recall=0.9580
# [hybrid_mid_coatnet2_unet_forniceal_palpebral | Trial 0] New best overall val_dice=0.9249 -> saved /kaggle/working/eyes-defy-anemia/Segmentation/outputs/checkpoints/best_hybrid_mid_coatnet2_unet_forniceal_palpebral.pth (fp16)
# [hybrid_mid_coatnet2_unet_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch  9/30 - train_loss=0.3028 val_loss=0.2818 val_dice=0.9249 val_iou=0.8618 val_precision=0.9342 val_recall=0.9191
# [hybrid_mid_coatnet2_unet_forniceal_palpebral | Trial 0 | loss_fn=bce_dice] Epoch
# Trials run: 12
# Best trial: #9
# Best validation Dice: 0.9291
# Best validation IoU:  0.8693
# Best hyperparameters:
#   learning_rate: 8.200518402245828e-05
#   weight_decay: 1.9634341572933354e-06
#   loss_fn: bce_dice
#
# --- Measuring architecture properties (params, inference latency) ---
# Parameters: 77,965,273
# Inference latency (batch_size=1, 224x224): 22.86 ms
#
# --- Final test-set evaluation (best_hybrid_mid_coatnet2_unet_forniceal_palpebral.pth) ---
# Overall test Dice=0.9279 IoU=0.8668 Precision=0.9180 Recall=0.9412 HD95=6.98px (undefined for 0/33 patients)
#            dice     iou  precision  recall    hd95
# country
# India    0.9262  0.8635     0.9200  0.9370  7.9470
# Italy    0.9294  0.8695     0.9164  0.9448  6.1653
#
# --- Per-loss-function comparison ---
#                 count      mean       max
# params_loss_fn
# bce_dice            7  0.920678  0.929141
# focal_tversky       5  0.916834  0.924892
#
# Saved per-trial metrics to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/hybrid_mid_coatnet2_unet_forniceal_palpebral_trials.csv
# Saved best-trial summary to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/hybrid_mid_coatnet2_unet_forniceal_palpebral_study_summary.json
# Saved per-patient test-set metrics to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/hybrid_mid_coatnet2_unet_forniceal_palpebral_test_per_patient.csv
# Saved 6 plots to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/plots:
#   hybrid_mid_coatnet2_unet_forniceal_palpebral_training_curves.png
#   hybrid_mid_coatnet2_unet_forniceal_palpebral_dice_iou_curve.png
#   hybrid_mid_coatnet2_unet_forniceal_palpebral_loss_fn_comparison.png
#   hybrid_mid_coatnet2_unet_forniceal_palpebral_test_summary.png
#   hybrid_mid_coatnet2_unet_forniceal_palpebral_test_by_country.png
#   hybrid_mid_coatnet2_unet_forniceal_palpebral_test_per_patient_dice.png
# [sync_outputs] 40 files consolidated under /kaggle/working/outputs, zipped to /kaggle/working/segmentation_sweep_results.zip

# %%
# Mid tier, combo 11/18 -- Swin-Base + UperNet (Transformer, ~121.3M), palpebral
# !python Segmentation/scripts/train_pretrained/train_transformer_mid_swin_base_upernet_palpebral.py
sync_outputs()
# Out:
# Using device: cuda
# Model: transformer_mid_swin_base_upernet_palpebral (pretrained build_model)
# Dataset: AlignedConjunctivaSegmentationDataset (tissue_type=palpebral)
# Image size: 512
# [I 2026-08-10 18:36:22,286] A new study created in memory with name: no-name-59e2e1cc-684c-42b1-ac68-5733d43d2b3f
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 8.98kB [00:00, 8.20MB/s]
# model.safetensors: 100%|█████████████████████| 490M/490M [00:09<00:00, 54.1MB/s]
# Loading weights: 100%|█| 535/535 [00:00<00:00, 619.82it/s, Materializing param=d
# UperNetForSemanticSegmentation LOAD REPORT from: openmmlab/upernet-swin-base
# Key                              | Status   |
# ---------------------------------+----------+---------------------------------------------------------------------------------------------------
# auxiliary_head.classifier.bias   | MISMATCH | Reinit due to size mismatch ckpt: torch.Size([150]) vs model:torch.Size([1])
# decode_head.classifier.weight    | MISMATCH | Reinit due to size mismatch ckpt: torch.Size([150, 512, 1, 1]) vs model:torch.Size([1, 512, 1, 1])
# decode_head.classifier.bias      | MISMATCH | Reinit due to size mismatch ckpt: torch.Size([150]) vs model:torch.Size([1])
# auxiliary_head.classifier.weight | MISMATCH | Reinit due to size mismatch ckpt: torch.Size([150, 256, 1, 1]) vs model:torch.Size([1, 256, 1, 1])
#
# Notes:
# - MISMATCH	:ckpt weights were loaded, but they did not match the original empty weight shapes.
# [W 2026-08-10 18:36:35,497] Trial 0 failed with parameters: {'learning_rate': 0.0001329291894316216, 'weight_decay': 0.0007114476009343421, 'loss_fn': 'bce_dice'} because of the following error: OutOfMemoryError('CUDA out of memory. Tried to allocate 128.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 124.81 MiB is free. Including non-PyTorch memory, this process has 14.44 GiB memory in use. Of the allocated memory 13.73 GiB is allocated by PyTorch, and 590.07 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)').
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/trainer_engine.py", line 393, in objective
#     train_loss = train_one_epoch(model, train_loader, optimizer, criterion, DEVICE)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/trainer_engine.py", line 187, in train_one_epoch
#     logits = model(images)
#              ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/models/segmentation/pretrained_registry.py", line 75, in forward
#     logits = self.hf_model(pixel_values=x).logits
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/upernet/modeling_upernet.py", line 339, in forward
#     outputs = self.backbone.forward_with_filtered_kwargs(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/backbone_utils.py", line 242, in forward_with_filtered_kwargs
#     return self(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 1166, in forward
#     outputs = self.encoder(
#               ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 757, in forward
#     layer_outputs = layer_module(hidden_states, input_dimensions, output_attentions, always_partition)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_layers.py", line 93, in __call__
#     return super().__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 692, in forward
#     layer_outputs = layer_module(hidden_states, input_dimensions, output_attentions, always_partition)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 649, in forward
#     layer_output = self.intermediate(layer_output)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 518, in forward
#     hidden_states = self.intermediate_act_fn(hidden_states)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/activations.py", line 89, in forward
#     return self.act(input)
#            ^^^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 128.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 124.81 MiB is free. Including non-PyTorch memory, this process has 14.44 GiB memory in use. Of the allocated memory 13.73 GiB is allocated by PyTorch, and 590.07 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# [W 2026-08-10 18:36:35,511] Trial 0 failed with value None.
# Traceback (most recent call last):
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/train_pretrained/train_transformer_mid_swin_base_upernet_palpebral.py", line 22, in <module>
#     run_study(
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/trainer_engine.py", line 476, in run_study
#     study.optimize(
#   File "/usr/local/lib/python3.12/dist-packages/optuna/study/study.py", line 516, in optimize
#     _optimize(
#   File "/usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py", line 68, in _optimize
#     _optimize_sequential(
#   File "/usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py", line 165, in _optimize_sequential
#     frozen_trial_id = _run_trial(study, func, catch)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py", line 263, in _run_trial
#     raise func_err
#   File "/usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/trainer_engine.py", line 393, in objective
#     train_loss = train_one_epoch(model, train_loader, optimizer, criterion, DEVICE)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/trainer_engine.py", line 187, in train_one_epoch
#     logits = model(images)
#              ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/models/segmentation/pretrained_registry.py", line 75, in forward
#     logits = self.hf_model(pixel_values=x).logits
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/upernet/modeling_upernet.py", line 339, in forward
#     outputs = self.backbone.forward_with_filtered_kwargs(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/backbone_utils.py", line 242, in forward_with_filtered_kwargs
#     return self(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 1166, in forward
#     outputs = self.encoder(
#               ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 757, in forward
#     layer_outputs = layer_module(hidden_states, input_dimensions, output_attentions, always_partition)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_layers.py", line 93, in __call__
#     return super().__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 692, in forward
#     layer_outputs = layer_module(hidden_states, input_dimensions, output_attentions, always_partition)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 649, in forward
#     layer_output = self.intermediate(layer_output)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 518, in forward
#     hidden_states = self.intermediate_act_fn(hidden_states)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/activations.py", line 89, in forward
#     return self.act(input)
#            ^^^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 128.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 124.81 MiB is free. Including non-PyTorch memory, this process has 14.44 GiB memory in use. Of the allocated memory 13.73 GiB is allocated by PyTorch, and 590.07 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# [sync_outputs] 40 files consolidated under /kaggle/working/outputs, zipped to /kaggle/working/segmentation_sweep_results.zip

# %%
# Mid tier, combo 12/18 -- Swin-Base + UperNet (Transformer, ~121.3M), forniceal_palpebral
# !python Segmentation/scripts/train_pretrained/train_transformer_mid_swin_base_upernet_forniceal_palpebral.py
sync_outputs()
# Out:
# Using device: cuda
# Model: transformer_mid_swin_base_upernet_forniceal_palpebral (pretrained build_model)
# Dataset: AlignedConjunctivaSegmentationDataset (tissue_type=forniceal_palpebral)
# Image size: 512
# [I 2026-08-10 18:37:20,593] A new study created in memory with name: no-name-4ce8b989-45de-4b24-a6c2-3f97a690fd08
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|█| 535/535 [00:00<00:00, 739.79it/s, Materializing param=d
# UperNetForSemanticSegmentation LOAD REPORT from: openmmlab/upernet-swin-base
# Key                              | Status   |
# ---------------------------------+----------+---------------------------------------------------------------------------------------------------
# decode_head.classifier.bias      | MISMATCH | Reinit due to size mismatch ckpt: torch.Size([150]) vs model:torch.Size([1])
# decode_head.classifier.weight    | MISMATCH | Reinit due to size mismatch ckpt: torch.Size([150, 512, 1, 1]) vs model:torch.Size([1, 512, 1, 1])
# auxiliary_head.classifier.weight | MISMATCH | Reinit due to size mismatch ckpt: torch.Size([150, 256, 1, 1]) vs model:torch.Size([1, 256, 1, 1])
# auxiliary_head.classifier.bias   | MISMATCH | Reinit due to size mismatch ckpt: torch.Size([150]) vs model:torch.Size([1])
#
# Notes:
# - MISMATCH	:ckpt weights were loaded, but they did not match the original empty weight shapes.
# [W 2026-08-10 18:37:23,419] Trial 0 failed with parameters: {'learning_rate': 0.0001329291894316216, 'weight_decay': 0.0007114476009343421, 'loss_fn': 'bce_dice'} because of the following error: OutOfMemoryError('CUDA out of memory. Tried to allocate 128.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 124.81 MiB is free. Including non-PyTorch memory, this process has 14.44 GiB memory in use. Of the allocated memory 13.73 GiB is allocated by PyTorch, and 590.07 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)').
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/trainer_engine.py", line 393, in objective
#     train_loss = train_one_epoch(model, train_loader, optimizer, criterion, DEVICE)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/trainer_engine.py", line 187, in train_one_epoch
#     logits = model(images)
#              ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/models/segmentation/pretrained_registry.py", line 75, in forward
#     logits = self.hf_model(pixel_values=x).logits
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/upernet/modeling_upernet.py", line 339, in forward
#     outputs = self.backbone.forward_with_filtered_kwargs(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/backbone_utils.py", line 242, in forward_with_filtered_kwargs
#     return self(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 1166, in forward
#     outputs = self.encoder(
#               ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 757, in forward
#     layer_outputs = layer_module(hidden_states, input_dimensions, output_attentions, always_partition)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_layers.py", line 93, in __call__
#     return super().__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 692, in forward
#     layer_outputs = layer_module(hidden_states, input_dimensions, output_attentions, always_partition)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 649, in forward
#     layer_output = self.intermediate(layer_output)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 518, in forward
#     hidden_states = self.intermediate_act_fn(hidden_states)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/activations.py", line 89, in forward
#     return self.act(input)
#            ^^^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 128.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 124.81 MiB is free. Including non-PyTorch memory, this process has 14.44 GiB memory in use. Of the allocated memory 13.73 GiB is allocated by PyTorch, and 590.07 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# [W 2026-08-10 18:37:23,423] Trial 0 failed with value None.
# Traceback (most recent call last):
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/train_pretrained/train_transformer_mid_swin_base_upernet_forniceal_palpebral.py", line 22, in <module>
#     run_study(
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/trainer_engine.py", line 476, in run_study
#     study.optimize(
#   File "/usr/local/lib/python3.12/dist-packages/optuna/study/study.py", line 516, in optimize
#     _optimize(
#   File "/usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py", line 68, in _optimize
#     _optimize_sequential(
#   File "/usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py", line 165, in _optimize_sequential
#     frozen_trial_id = _run_trial(study, func, catch)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py", line 263, in _run_trial
#     raise func_err
#   File "/usr/local/lib/python3.12/dist-packages/optuna/study/_optimize.py", line 206, in _run_trial
#     value_or_values = func(trial)
#                       ^^^^^^^^^^^
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/trainer_engine.py", line 393, in objective
#     train_loss = train_one_epoch(model, train_loader, optimizer, criterion, DEVICE)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/trainer_engine.py", line 187, in train_one_epoch
#     logits = model(images)
#              ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/models/segmentation/pretrained_registry.py", line 75, in forward
#     logits = self.hf_model(pixel_values=x).logits
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/upernet/modeling_upernet.py", line 339, in forward
#     outputs = self.backbone.forward_with_filtered_kwargs(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/utils/backbone_utils.py", line 242, in forward_with_filtered_kwargs
#     return self(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 1166, in forward
#     outputs = self.encoder(
#               ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 757, in forward
#     layer_outputs = layer_module(hidden_states, input_dimensions, output_attentions, always_partition)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/modeling_layers.py", line 93, in __call__
#     return super().__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 692, in forward
#     layer_outputs = layer_module(hidden_states, input_dimensions, output_attentions, always_partition)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 649, in forward
#     layer_output = self.intermediate(layer_output)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/models/swin/modeling_swin.py", line 518, in forward
#     hidden_states = self.intermediate_act_fn(hidden_states)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/transformers/activations.py", line 89, in forward
#     return self.act(input)
#            ^^^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 128.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 124.81 MiB is free. Including non-PyTorch memory, this process has 14.44 GiB memory in use. Of the allocated memory 13.73 GiB is allocated by PyTorch, and 590.07 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# [sync_outputs] 40 files consolidated under /kaggle/working/outputs, zipped to /kaggle/working/segmentation_sweep_results.zip

# %% [markdown]
# ## Done — what to download
#
# Everything from this tier is consolidated at `/kaggle/working/outputs/` (checkpoints, logs) and zipped to `/kaggle/working/segmentation_sweep_results.zip`. Both are visible in this notebook version's **Output** tab once you Save Version -> Save & Run All — download the zip directly from there. Download and keep this zip somewhere safe (e.g. manually to Google Drive) before running the Strong-tier notebook in a fresh session, since each tier notebook's `/kaggle/working` starts empty.
#
# A failed `!python ...` cell does **not** halt "Run All" — check each script's own printed output (or the saved `Segmentation/outputs/logs/*_study_summary.json` files) after this finishes, not just whether the notebook run itself completed.

# %%
from pathlib import Path

print('Final contents of /kaggle/working/outputs:')
for f in sorted(Path('/kaggle/working/outputs').rglob('*')):
    if f.is_file():
        print(f'  {f.relative_to("/kaggle/working/outputs")}  ({f.stat().st_size / 1e6:.2f} MB)')

zip_path = Path('/kaggle/working/segmentation_sweep_results.zip')
print(f"\nZip archive: {zip_path}  ({zip_path.stat().st_size / 1e6:.2f} MB)")
# Out:
# Final contents of /kaggle/working/outputs:
#   checkpoints/best_cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral.pth  (91.81 MB)
#   checkpoints/best_cnn_mid_resnet101_deeplabv3plus_palpebral.pth  (91.81 MB)
#   checkpoints/best_hybrid_mid_coatnet2_unet_forniceal_palpebral.pth  (156.17 MB)
#   checkpoints/best_hybrid_mid_coatnet2_unet_palpebral.pth  (156.17 MB)
#   logs/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_study_summary.json  (0.00 MB)
#   logs/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_test_per_patient.csv  (0.00 MB)
#   logs/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_trials.csv  (0.07 MB)
#   logs/cnn_mid_resnet101_deeplabv3plus_palpebral_study_summary.json  (0.00 MB)
#   logs/cnn_mid_resnet101_deeplabv3plus_palpebral_test_per_patient.csv  (0.00 MB)
#   logs/cnn_mid_resnet101_deeplabv3plus_palpebral_trials.csv  (0.07 MB)
#   logs/hybrid_mid_coatnet2_unet_forniceal_palpebral_study_summary.json  (0.00 MB)
#   logs/hybrid_mid_coatnet2_unet_forniceal_palpebral_test_per_patient.csv  (0.00 MB)
#   logs/hybrid_mid_coatnet2_unet_forniceal_palpebral_trials.csv  (0.07 MB)
#   logs/hybrid_mid_coatnet2_unet_palpebral_study_summary.json  (0.00 MB)
#   logs/hybrid_mid_coatnet2_unet_palpebral_test_per_patient.csv  (0.00 MB)
#   logs/hybrid_mid_coatnet2_unet_palpebral_trials.csv  (0.08 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_dice_iou_curve.png  (0.06 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_loss_fn_comparison.png  (0.03 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_test_by_country.png  (0.04 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_test_per_patient_dice.png  (0.03 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_test_summary.png  (0.04 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_forniceal_palpebral_training_curves.png  (0.11 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_palpebral_dice_iou_curve.png  (0.06 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_palpebral_loss_fn_comparison.png  (0.03 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_palpebral_test_by_country.png  (0.04 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_palpebral_test_per_patient_dice.png  (0.03 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_palpebral_test_summary.png  (0.04 MB)
#   plots/cnn_mid_resnet101_deeplabv3plus_palpebral_training_curves.png  (0.12 MB)
#   plots/hybrid_mid_coatnet2_unet_forniceal_palpebral_dice_iou_curve.png  (0.05 MB)
#   plots/hybrid_mid_coatnet2_unet_forniceal_palpebral_loss_fn_comparison.png  (0.03 MB)
#   plots/hybrid_mid_coatnet2_unet_forniceal_palpebral_test_by_country.png  (0.04 MB)
#   plots/hybrid_mid_coatnet2_unet_forniceal_palpebral_test_per_patient_dice.png  (0.03 MB)
#   plots/hybrid_mid_coatnet2_unet_forniceal_palpebral_test_summary.png  (0.04 MB)
#   plots/hybrid_mid_coatnet2_unet_forniceal_palpebral_training_curves.png  (0.11 MB)
#   plots/hybrid_mid_coatnet2_unet_palpebral_dice_iou_curve.png  (0.06 MB)
#   plots/hybrid_mid_coatnet2_unet_palpebral_loss_fn_comparison.png  (0.03 MB)
#   plots/hybrid_mid_coatnet2_unet_palpebral_test_by_country.png  (0.04 MB)
#   plots/hybrid_mid_coatnet2_unet_palpebral_test_per_patient_dice.png  (0.03 MB)
#   plots/hybrid_mid_coatnet2_unet_palpebral_test_summary.png  (0.04 MB)
#   plots/hybrid_mid_coatnet2_unet_palpebral_training_curves.png  (0.12 MB)
#
# Zip archive: /kaggle/working/segmentation_sweep_results.zip  (458.41 MB)
