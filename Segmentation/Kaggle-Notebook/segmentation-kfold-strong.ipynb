# %% [markdown]
# # EYES-DEFY-ANEMIA — K-fold re-training: Strong tier (4 of 12 combos)
#
# One of **3 tier-specific notebooks** (Base / Mid / Strong), covering the 12 combos that completed the original 18-combo Optuna sweep (the 6 Transformer-family combos OOM'd and are out of scope here). Each notebook re-trains its tier's combos using their own already-found best hyperparameters (no re-tuning) under **3-fold cross-validation** (`Segmentation/scripts/train_pretrained_kfold/kfold_engine.py`), so the reported test-set metric is a mean ± std across 3 independent trainings instead of one point estimate.
#
# **This notebook covers:**
# - ConvNeXt-Large U-Net (CNN, ~203.3M), `palpebral`
# - ConvNeXt-Large U-Net (CNN, ~203.3M), `forniceal_palpebral`
# - TransUNet (Hybrid, ~120.9M), `palpebral`
# - TransUNet (Hybrid, ~120.9M), `forniceal_palpebral`
#
# **Estimated time: ~5.7h worst-case (ConvNeXt-Large ~4.1h + TransUNet ~1.6h)** — comfortably within one 12h Kaggle session.
#
# **Confirmed settings:** `BATCH_SIZE=32`, `MAX_EPOCHS=250`, `EARLY_STOPPING_PATIENCE=7`, `ReduceLROnPlateau` LR scheduler (factor=0.5, patience=3) — none of trainer_engine.py's original Optuna-sweep settings (30 epochs, patience 5, batch 16, no scheduler) apply here. Full rationale and design decisions: `Segmentation/.project_memory/05_kfold_reevaluation.md`.
#
# Run the 3 tier notebooks independently, in separate Kaggle sessions.

# %% [markdown]
# ## Setup

# %%
import torch

print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# CUDA available: True
# GPU: Tesla T4

# %%
# rm -rf first so a re-run within the same kernel session stays idempotent
# instead of nesting a second clone inside the first.
# !rm -rf eyes-defy-anemia
# !git clone https://github.com/manivafapour/eyes-defy-anemia.git
# %cd eyes-defy-anemia
# Out:
# Cloning into 'eyes-defy-anemia'...
# remote: Enumerating objects: 1704, done.
# remote: Counting objects: 100% (1385/1385), done.
# remote: Compressing objects: 100% (944/944), done.
# remote: Total 1704 (delta 570), reused 1206 (delta 427), pack-reused 319 (from 1)
# Receiving objects: 100% (1704/1704), 100.79 MiB | 33.71 MiB/s, done.
# Resolving deltas: 100% (733/733), done.
# /kaggle/working/eyes-defy-anemia

# %%
# Diagnostic, not a hardcoded assumption -- Kaggle's actual dataset mount
# path does not always match its display name, and can be nested deeper
# than expected (this project has been bitten by this before, twice now:
# see classification/.project_memory/kaggle/01_kaggle_notes.md -- real
# paths have landed under /kaggle/input/datasets/<username>/<slug>/, not
# directly under /kaggle/input/<slug>/). Recurses a few levels deep so
# this is caught in one pass instead of needing to descend manually.
# Read the output below, THEN set the dataset dir variable(s) in the next cell.
import os


def print_tree(path, depth=0, max_depth=4):
    for entry in sorted(os.listdir(path)):
        full = os.path.join(path, entry)
        print("  " * depth + entry)
        if os.path.isdir(full) and depth < max_depth:
            print_tree(full, depth + 1, max_depth)


print_tree("/kaggle/input")
# Out:
# datasets
#   manivafapour21
#     aligned-raw
#       aligned_raw
#         alignment_log.csv
#         images
#         masks
#     aligned-raw-forniceal
#       aligned_raw_forniceal
#         alignment_log.csv
#         images
#         masks

# %% [markdown]
# **Before running the next cell:** attach your uploaded dataset(s) to this notebook -- either both zips together as ONE Kaggle dataset, or as TWO SEPARATE datasets (this is what actually happened the first time this notebook was run: Kaggle listed them individually in the Input panel as `aligned_raw` and `aligned_raw_forniceal`). Either way, run the listing cell above, read its REAL printed output, and set the path(s) below from that -- **not** the placeholder text left in by default, and not a guessed path based on the dataset's display name (Kaggle's actual mount path does not always match it).

# %%
# Confirmed real mount paths (project author's Kaggle account, verified via
# the print_tree() listing above on 2026-08-08 -- see
# Segmentation/.project_memory/kaggle/01_kaggle_notes.md for the full
# doubly-nested structure this came from). If you re-attach the datasets
# under a different username/slug, or Kaggle changes its mount scheme again,
# re-run the listing cell above and update these two lines from its real
# output -- don't guess.
ALIGNED_RAW_DATASET_DIR = "/kaggle/input/datasets/manivafapour21/aligned-raw"
ALIGNED_RAW_FORNICEAL_DATASET_DIR = "/kaggle/input/datasets/manivafapour21/aligned-raw-forniceal"

# %%
# Only packages actually missing from Kaggle's base image (torch/torchvision,
# opencv, pandas, PIL, scikit-learn -- and therefore scipy AND sklearn's
# StratifiedKFold, its own dependency -- are already there; scipy is listed
# explicitly anyway rather than silently assumed, since it is a real,
# load-bearing dependency for HD95 in segmentation_metrics.py. No optuna
# here -- these notebooks re-train with FIXED hyperparameters (each combo's
# own best_params from the earlier Optuna sweep), not a fresh search.
# Deliberately NOT `pip install -r requirements.txt` -- that file is pinned
# to the local Windows/CUDA 13.0 build and would try to reinstall Kaggle's
# own correctly configured GPU PyTorch with an incompatible build.
# !pip install -q albumentations scipy segmentation-models-pytorch timm transformers einops
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 4.6 MB/s eta 0:00:00

# %% [markdown]
# ## Data

# %%
import shutil
import zipfile
from pathlib import Path

DST_ROOT = Path("Segmentation/data/processed")


def stage_tissue_data(name: str, dataset_dir: str):
    """Copies {name}/ from the given Kaggle-attached dataset directory into
    Segmentation/data/processed/{name}/. Tries three possible layouts rather
    than assuming one, since Kaggle can present an uploaded zip differently
    depending on upload method:
      1. dataset_dir/{name}/images,masks/  -- the zip's own internal "{name}/"
         prefix preserved as-is (this is how aligned_raw.zip/
         aligned_raw_forniceal.zip were actually built -- see
         Segmentation/scripts/build_aligned_dataset{,_forniceal}.py).
      2. dataset_dir/images,masks/         -- Kaggle stripped/flattened that
         top-level folder on extraction.
      3. dataset_dir/{name}.zip            -- never auto-extracted at all,
         still sitting there as a raw zip file.
    """
    dataset_dir = Path(dataset_dir)
    dst = DST_ROOT / name
    shutil.rmtree(dst, ignore_errors=True)

    nested_dir = dataset_dir / name
    flat_zip = dataset_dir / f"{name}.zip"

    if nested_dir.is_dir():
        shutil.copytree(nested_dir, dst)
    elif (dataset_dir / "images").is_dir() and (dataset_dir / "masks").is_dir():
        shutil.copytree(dataset_dir, dst)
    elif flat_zip.is_file():
        dst.mkdir(parents=True, exist_ok=True)
        with zipfile.ZipFile(flat_zip) as zf:
            zf.extractall(DST_ROOT)  # zip's own internal paths already start with f"{name}/"
    else:
        raise FileNotFoundError(
            f"Could not find {name}/, images+masks/, or {name}.zip under {dataset_dir} -- "
            f"run the /kaggle/input listing cell above and check what's actually there."
        )

    n_images = len(list((dst / "images").glob("*.jpg")))
    n_masks = len(list((dst / "masks").glob("*.png")))
    print(f"{name}: {n_images} images, {n_masks} masks staged at {dst}")


stage_tissue_data("aligned_raw", ALIGNED_RAW_DATASET_DIR)
stage_tissue_data("aligned_raw_forniceal", ALIGNED_RAW_FORNICEAL_DATASET_DIR)
# Out:
# aligned_raw: 201 images, 201 masks staged at Segmentation/data/processed/aligned_raw
# aligned_raw_forniceal: 211 images, 211 masks staged at Segmentation/data/processed/aligned_raw_forniceal

# %%
# Combined sanity check, run BEFORE any real training:
#   1. Confirm the pip-installed heavy dependencies actually work -- a
#      dataloader-only check would NOT catch a missing/broken install here
#      (classification's own Kaggle notes: a plain dataloader check only
#      exercises dataset.py's imports, so a missing package silently
#      surfaces only much later, on the first real training script).
#   2. Confirm the 9-model registry itself imports cleanly.
#   3. Pull one real batch from BOTH tissue-type dataloaders.
import sys
from pathlib import Path

sys.path.insert(0, str(Path("Segmentation/scripts").resolve()))
sys.path.insert(0, str(Path("Segmentation").resolve()))

import segmentation_models_pytorch as smp
import timm
import transformers
import einops

print("segmentation_models_pytorch", smp.__version__)
print("timm", timm.__version__)
print("transformers", transformers.__version__)
print("einops", einops.__version__)

from models.segmentation.pretrained_registry import ARCHITECTURE_REGISTRY
print(f"\n{len(ARCHITECTURE_REGISTRY)} architectures registered:")
for name in ARCHITECTURE_REGISTRY:
    print(" ", name)

from dataset import get_dataloaders

loaders = get_dataloaders()
for key in ["aligned_seg_train", "aligned_seg_forniceal_train"]:
    images, masks = next(iter(loaders[key]))
    print(f"\n{key}: image batch {tuple(images.shape)}, mask batch {tuple(masks.shape)}, "
          f"{len(loaders[key].dataset)} patients")
# Out:
# segmentation_models_pytorch 0.5.0
# timm 1.0.26
# transformers 5.0.0
# einops 0.8.2
#
# 9 architectures registered:
#   cnn_base_efficientnet_b1_unet
#   cnn_mid_resnet101_deeplabv3plus
#   cnn_strong_convnext_large_unet
#   hybrid_base_coatnet0_unet
#   hybrid_mid_coatnet2_unet
#   hybrid_strong_transunet
#   transformer_base_segformer_b2
#   transformer_mid_swin_base_upernet
#   transformer_strong_swin_large_upernet
#
# aligned_seg_train: image batch (16, 3, 256, 256), mask batch (16, 1, 256, 256), 143 patients
#
# aligned_seg_forniceal_train: image batch (16, 3, 256, 256), mask batch (16, 1, 256, 256), 147 patients

# %% [markdown]
# ## Training

# %%
import shutil
from pathlib import Path


def sync_outputs():
    """Consolidates Segmentation/outputs/{checkpoints,logs,plots}/ into a single
    top-level /kaggle/working/outputs/ folder and re-zips it to
    /kaggle/working/segmentation_sweep_results.zip. Called after EVERY
    training cell below, not just at the end -- if the run gets cut short
    partway through the 18 combos, whatever completed so far is still
    cleanly consolidated and zipped, ready to download.

    IMPORTANT (added after a real Kaggle disk-quota crash, "Your notebook
    tried to use more disk space than is available", 20.93GB used, failed
    5h40m into a real run): each of the 18 training scripts can write up to
    3 full checkpoint files at fp32 (best-overall + one per loss function),
    and none of that is ever deleted between combos -- for the larger
    architectures (ConvNeXt-Large ~203M params, Swin-Large ~234M, etc.)
    those add up to hundreds of MB to ~1GB EACH. Originally this function
    copied Segmentation/outputs/ into /kaggle/working/outputs/ and left the
    source in place, so between the untouched source, the mirrored copy,
    and the zip made from that copy, roughly 3 copies of everything
    produced so far existed on disk simultaneously -- comfortably enough to
    blow a ~20GB quota partway through the Mid/Strong tiers. Now the
    source is deleted right after it's safely copied into
    /kaggle/working/outputs/, which becomes the single accumulating copy
    (plus the zip made from it) -- every training script recreates
    Segmentation/outputs/{checkpoints,logs,plots}/ fresh via its own
    mkdir(parents=True, exist_ok=True) on its next run, so nothing is lost
    by clearing the source here.
    """
    results_dir = Path("/kaggle/working/outputs")
    results_dir.mkdir(parents=True, exist_ok=True)
    for sub in ["checkpoints", "logs", "plots"]:
        src = Path("Segmentation/outputs") / sub
        if src.exists():
            shutil.copytree(src, results_dir / sub, dirs_exist_ok=True)
            shutil.rmtree(src)
    archive_path = shutil.make_archive("/kaggle/working/segmentation_sweep_results", "zip", root_dir=str(results_dir))
    n_files = sum(1 for f in results_dir.rglob("*") if f.is_file())
    print(f"[sync_outputs] {n_files} files consolidated under {results_dir}, zipped to {archive_path}")


sync_outputs()  # harmless no-op now (nothing produced yet), confirms the function works before training starts
# Out:
# [sync_outputs] 0 files consolidated under /kaggle/working/outputs, zipped to /kaggle/working/segmentation_sweep_results.zip

# %% [markdown]
# ### K-fold re-training — Strong tier (4 combos)

# %%
# Strong tier, combo 1/4 -- ConvNeXt-Large U-Net (CNN, ~203.3M), palpebral (3 folds, fixed best hyperparameters)
# !python Segmentation/scripts/train_pretrained_kfold/train_kfold_cnn_strong_convnext_large_unet_palpebral.py
sync_outputs()
# Out:
# Using device: cuda
# Model: cnn_strong_convnext_large_unet_palpebral (K-fold re-training, fixed hyperparameters)
# tissue_type=palpebral image_size=256
# learning_rate=0.00017095488799868667 weight_decay=0.0009336898139653307 loss_fn=bce_dice
# n_folds=3 MAX_EPOCHS=250 EARLY_STOPPING_PATIENCE=7 BATCH_SIZE=32
# Pool (train+val, aligned): 170 patients
#
# === cnn_strong_convnext_large_unet_palpebral | Fold 1/3: train=113 val=57 ===
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors: 100%|██████████████████████| 791M/791M [00:07<00:00, 104MB/s]
# Traceback (most recent call last):
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/train_pretrained_kfold/train_kfold_cnn_strong_convnext_large_unet_palpebral.py", line 24, in <module>
#     run_kfold_study(
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/train_pretrained_kfold/kfold_engine.py", line 184, in run_kfold_study
#     train_loss = train_one_epoch(model, train_loader, optimizer, criterion, DEVICE)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/trainer_engine.py", line 187, in train_one_epoch
#     logits = model(images)
#              ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/segmentation_models_pytorch/base/model.py", line 67, in forward
#     decoder_output = self.decoder(features)
#                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/segmentation_models_pytorch/decoders/unet/decoder.py", line 168, in forward
#     x = decoder_block(x, height, width, skip_connection=skip_connection)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/segmentation_models_pytorch/decoders/unet/decoder.py", line 50, in forward
#     feature_map = F.interpolate(
#                   ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/functional.py", line 4812, in interpolate
#     return torch._C._nn.upsample_nearest2d(input, output_size, scale_factors)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 48.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 36.81 MiB is free. Including non-PyTorch memory, this process has 14.52 GiB memory in use. Of the allocated memory 14.32 GiB is allocated by PyTorch, and 80.77 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# [sync_outputs] 0 files consolidated under /kaggle/working/outputs, zipped to /kaggle/working/segmentation_sweep_results.zip

# %%
# Strong tier, combo 2/4 -- ConvNeXt-Large U-Net (CNN, ~203.3M), forniceal_palpebral (3 folds, fixed best hyperparameters)
# !python Segmentation/scripts/train_pretrained_kfold/train_kfold_cnn_strong_convnext_large_unet_forniceal_palpebral.py
sync_outputs()
# Out:
# Using device: cuda
# Model: cnn_strong_convnext_large_unet_forniceal_palpebral (K-fold re-training, fixed hyperparameters)
# tissue_type=forniceal_palpebral image_size=256
# learning_rate=0.000684792009557478 weight_decay=2.62108787826544e-06 loss_fn=focal_tversky
# n_folds=3 MAX_EPOCHS=250 EARLY_STOPPING_PATIENCE=7 BATCH_SIZE=32
# Pool (train+val, aligned): 178 patients
#
# === cnn_strong_convnext_large_unet_forniceal_palpebral | Fold 1/3: train=118 val=60 ===
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Traceback (most recent call last):
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/train_pretrained_kfold/train_kfold_cnn_strong_convnext_large_unet_forniceal_palpebral.py", line 24, in <module>
#     run_kfold_study(
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/train_pretrained_kfold/kfold_engine.py", line 184, in run_kfold_study
#     train_loss = train_one_epoch(model, train_loader, optimizer, criterion, DEVICE)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/eyes-defy-anemia/Segmentation/scripts/trainer_engine.py", line 187, in train_one_epoch
#     logits = model(images)
#              ^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/segmentation_models_pytorch/base/model.py", line 67, in forward
#     decoder_output = self.decoder(features)
#                      ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/segmentation_models_pytorch/decoders/unet/decoder.py", line 168, in forward
#     x = decoder_block(x, height, width, skip_connection=skip_connection)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/segmentation_models_pytorch/decoders/unet/decoder.py", line 50, in forward
#     feature_map = F.interpolate(
#                   ^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/functional.py", line 4812, in interpolate
#     return torch._C._nn.upsample_nearest2d(input, output_size, scale_factors)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.OutOfMemoryError: CUDA out of memory. Tried to allocate 48.00 MiB. GPU 0 has a total capacity of 14.56 GiB of which 36.81 MiB is free. Including non-PyTorch memory, this process has 14.52 GiB memory in use. Of the allocated memory 14.32 GiB is allocated by PyTorch, and 80.77 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)
# [sync_outputs] 0 files consolidated under /kaggle/working/outputs, zipped to /kaggle/working/segmentation_sweep_results.zip

# %%
# Strong tier, combo 3/4 -- TransUNet (Hybrid, ~120.9M), palpebral (3 folds, fixed best hyperparameters)
# !python Segmentation/scripts/train_pretrained_kfold/train_kfold_hybrid_strong_transunet_palpebral.py
sync_outputs()
# Out:
# Using device: cuda
# Model: hybrid_strong_transunet_palpebral (K-fold re-training, fixed hyperparameters)
# tissue_type=palpebral image_size=256
# learning_rate=0.00314288089084011 weight_decay=4.335281794951567e-06 loss_fn=focal_tversky
# n_folds=3 MAX_EPOCHS=250 EARLY_STOPPING_PATIENCE=7 BATCH_SIZE=32
# Pool (train+val, aligned): 170 patients
#
# === hybrid_strong_transunet_palpebral | Fold 1/3: train=113 val=57 ===
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# model.safetensors: 100%|█████████████████████| 102M/102M [00:03<00:00, 33.8MB/s]
# model.safetensors: 100%|█████████████████████| 346M/346M [00:05<00:00, 69.1MB/s]
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch   1/250 - train_loss=0.7995 val_loss=0.8466 val_dice=0.0740 val_iou=0.0386 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch   2/250 - train_loss=0.7310 val_loss=0.8429 val_dice=0.0752 val_iou=0.0392 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch   3/250 - train_loss=0.7102 val_loss=0.8382 val_dice=0.0782 val_iou=0.0409 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch   4/250 - train_loss=0.6944 val_loss=0.8936 val_dice=0.0184 val_iou=0.0094 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch   5/250 - train_loss=0.6808 val_loss=0.8384 val_dice=0.0677 val_iou=0.0354 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch   6/250 - train_loss=0.6676 val_loss=0.7620 val_dice=0.2343 val_iou=0.1350 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch   7/250 - train_loss=0.6531 val_loss=0.7307 val_dice=0.2001 val_iou=0.1129 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch   8/250 - train_loss=0.6380 val_loss=0.7974 val_dice=0.1027 val_iou=0.0545 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch   9/250 - train_loss=0.6214 val_loss=0.7843 val_dice=0.1179 val_iou=0.0631 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch  10/250 - train_loss=0.6037 val_loss=0.7097 val_dice=0.6768 val_iou=0.5348 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch  11/250 - train_loss=0.5831 val_loss=0.8052 val_dice=0.0733 val_iou=0.0431 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch  12/250 - train_loss=0.5602 val_loss=0.7313 val_dice=0.5550 val_iou=0.4070 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch  13/250 - train_loss=0.5357 val_loss=0.7089 val_dice=0.5980 val_iou=0.4501 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch  14/250 - train_loss=0.5106 val_loss=0.6435 val_dice=0.6887 val_iou=0.5511 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch  15/250 - train_loss=0.4838 val_loss=0.5168 val_dice=0.6727 val_iou=0.5149 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch  16/250 - train_loss=0.4565 val_loss=0.4794 val_dice=0.7674 val_iou=0.6299 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch  17/250 - train_loss=0.4238 val_loss=0.4594 val_dice=0.7799 val_iou=0.6463 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch  18/250 - train_loss=0.3918 val_loss=0.5287 val_dice=0.4039 val_iou=0.2613 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch  19/250 - train_loss=0.3603 val_loss=0.5427 val_dice=0.6776 val_iou=0.5324 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold 1/3] Epoch  20/250 - train_loss=0.3342 val_loss=0.4172 val_dice=0.7461 val_iou=0.6041 lr=3.14e-03
# [hybrid_strong_transunet_palpebral | fold
lr=1.57e-03
# [hybrid_strong_transunet_palpebral | fold 3/3] Epoch  43/250 - train_loss=0.1079 val_loss=0.1702 val_dice=0.8350 val_iou=0.7266 lr=1.57e-03
# [hybrid_strong_transunet_palpebral | fold 3/3] Epoch  44/250 - train_loss=0.1035 val_loss=0.2870 val_dice=0.7435 val_iou=0.6170 lr=1.57e-03
# [hybrid_strong_transunet_palpebral | fold 3/3] Epoch  45/250 - train_loss=0.1077 val_loss=0.1505 val_dice=0.7727 val_iou=0.6373 lr=1.57e-03
# [hybrid_strong_transunet_palpebral | fold 3/3] Epoch  46/250 - train_loss=0.1000 val_loss=0.1540 val_dice=0.7487 val_iou=0.6062 lr=1.57e-03
# [hybrid_strong_transunet_palpebral | fold 3/3] Epoch  47/250 - train_loss=0.0953 val_loss=0.1732 val_dice=0.8294 val_iou=0.7181 lr=1.57e-03
# [hybrid_strong_transunet_palpebral | fold 3/3] Epoch  48/250 - train_loss=0.0930 val_loss=0.1279 val_dice=0.8458 val_iou=0.7374 lr=1.57e-03
# [hybrid_strong_transunet_palpebral | fold 3/3] Epoch  49/250 - train_loss=0.0902 val_loss=0.1333 val_dice=0.8419 val_iou=0.7319 lr=1.57e-03
# [hybrid_strong_transunet_palpebral | fold 3/3] Epoch  50/250 - train_loss=0.0833 val_loss=0.1384 val_dice=0.8487 val_iou=0.7426 lr=1.57e-03
# [hybrid_strong_transunet_palpebral | fold 3/3] Epoch  51/250 - train_loss=0.0783 val_loss=0.1314 val_dice=0.8433 val_iou=0.7347 lr=1.57e-03
# [hybrid_strong_transunet_palpebral | fold 3/3] Epoch  52/250 - train_loss=0.0744 val_loss=0.1190 val_dice=0.8464 val_iou=0.7387 lr=1.57e-03
# [hybrid_strong_transunet_palpebral | fold 3/3] Epoch  53/250 - train_loss=0.0719 val_loss=0.1228 val_dice=0.8233 val_iou=0.7050 lr=1.57e-03
# [hybrid_strong_transunet_palpebral | fold 3/3] Epoch  54/250 - train_loss=0.0701 val_loss=0.1225 val_dice=0.8391 val_iou=0.7284 lr=1.57e-03
# [hybrid_strong_transunet_palpebral | fold 3/3] Epoch  55/250 - train_loss=0.0711 val_loss=0.1520 val_dice=0.8237 val_iou=0.7063 lr=1.57e-03
# [hybrid_strong_transunet_palpebral | fold 3/3] Epoch  56/250 - train_loss=0.0710 val_loss=0.1328 val_dice=0.8412 val_iou=0.7310 lr=7.86e-04
# [hybrid_strong_transunet_palpebral | fold 3/3] Epoch  57/250 - train_loss=0.0681 val_loss=0.1578 val_dice=0.8323 val_iou=0.7214 lr=7.86e-04
# [hybrid_strong_transunet_palpebral | fold 3/3] Epoch  58/250 - train_loss=0.0636 val_loss=0.1416 val_dice=0.8366 val_iou=0.7259 lr=7.86e-04
# [hybrid_strong_transunet_palpebral | fold 3/3] Epoch  59/250 - train_loss=0.0618 val_loss=0.1336 val_dice=0.8443 val_iou=0.7377 lr=7.86e-04
# [hybrid_strong_transunet_palpebral | fold 3] Early stopping at epoch 59 (no val_loss improvement for 7 epochs).
# --- Fold 3 test-set evaluation (best_hybrid_strong_transunet_palpebral_fold3.pth) ---
# Fold 3 test Dice=0.8309 IoU=0.7199 HD95=11.63px
#
# --- Measuring architecture properties (params, inference latency) ---
# Parameters: 120,876,817
# Inference latency (batch_size=1, 256x256): 17.03 ms
#
# Saved per-fold summary to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/hybrid_strong_transunet_palpebral_kfold_folds.csv
#
# --- Aggregate across folds (mean +/- std) ---
#   dice       = 0.8265 +/- 0.0105
#   iou        = 0.7162 +/- 0.0102
#   precision  = 0.8611 +/- 0.0194
#   recall     = 0.8129 +/- 0.0307
#   hd95       = 12.2743 +/- 0.5745
# Saved per-patient-per-fold test metrics to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/hybrid_strong_transunet_palpebral_kfold_test_per_patient.csv
# Saved K-fold summary to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/hybrid_strong_transunet_palpebral_kfold_summary.json
# Saved 5 plots to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/plots:
#   hybrid_strong_transunet_palpebral_kfold_mean_curve.png
#   hybrid_strong_transunet_palpebral_fold_dice_distribution.png
#   hybrid_strong_transunet_palpebral_test_summary.png
#   hybrid_strong_transunet_palpebral_test_by_country.png
#   hybrid_strong_transunet_palpebral_test_per_patient_dice.png
# [sync_outputs] 11 files consolidated under /kaggle/working/outputs, zipped to /kaggle/working/segmentation_sweep_results.zip

# %%
# Strong tier, combo 4/4 -- TransUNet (Hybrid, ~120.9M), forniceal_palpebral (3 folds, fixed best hyperparameters)
# !python Segmentation/scripts/train_pretrained_kfold/train_kfold_hybrid_strong_transunet_forniceal_palpebral.py
sync_outputs()
# Out:
# Using device: cuda
# Model: hybrid_strong_transunet_forniceal_palpebral (K-fold re-training, fixed hyperparameters)
# tissue_type=forniceal_palpebral image_size=256
# learning_rate=0.0005987474910461401 weight_decay=1.3783237455007196e-06 loss_fn=bce_dice
# n_folds=3 MAX_EPOCHS=250 EARLY_STOPPING_PATIENCE=7 BATCH_SIZE=32
# Pool (train+val, aligned): 178 patients
#
# === hybrid_strong_transunet_forniceal_palpebral | Fold 1/3: train=118 val=60 ===
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch   1/250 - train_loss=0.7079 val_loss=0.7534 val_dice=0.2350 val_iou=0.1424 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch   2/250 - train_loss=0.6169 val_loss=0.7406 val_dice=0.4097 val_iou=0.2644 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch   3/250 - train_loss=0.5762 val_loss=0.7016 val_dice=0.4604 val_iou=0.3084 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch   4/250 - train_loss=0.5527 val_loss=0.6748 val_dice=0.4533 val_iou=0.3048 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch   5/250 - train_loss=0.5412 val_loss=0.6837 val_dice=0.6204 val_iou=0.4737 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch   6/250 - train_loss=0.5324 val_loss=0.6476 val_dice=0.6281 val_iou=0.4863 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch   7/250 - train_loss=0.5261 val_loss=0.5826 val_dice=0.7935 val_iou=0.6720 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch   8/250 - train_loss=0.5204 val_loss=0.5688 val_dice=0.8221 val_iou=0.7099 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch   9/250 - train_loss=0.5146 val_loss=0.5598 val_dice=0.8241 val_iou=0.7131 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch  10/250 - train_loss=0.5103 val_loss=0.5434 val_dice=0.8936 val_iou=0.8122 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch  11/250 - train_loss=0.5055 val_loss=0.5369 val_dice=0.8962 val_iou=0.8161 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch  12/250 - train_loss=0.5001 val_loss=0.5337 val_dice=0.8924 val_iou=0.8101 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch  13/250 - train_loss=0.4956 val_loss=0.5232 val_dice=0.8988 val_iou=0.8199 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch  14/250 - train_loss=0.4900 val_loss=0.5105 val_dice=0.8998 val_iou=0.8211 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch  15/250 - train_loss=0.4857 val_loss=0.5282 val_dice=0.8435 val_iou=0.7387 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch  16/250 - train_loss=0.4818 val_loss=0.5065 val_dice=0.8918 val_iou=0.8091 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch  17/250 - train_loss=0.4762 val_loss=0.4960 val_dice=0.8979 val_iou=0.8182 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch  18/250 - train_loss=0.4719 val_loss=0.4922 val_dice=0.9042 val_iou=0.8281 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch  19/250 - train_loss=0.4669 val_loss=0.4894 val_dice=0.8711 val_iou=0.7777 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch  20/250 - train_loss=0.4614 val_loss=0.4825 val_dice=0.8848 val_iou=0.7978 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch  21/250 - train_loss=0.4574 val_loss=0.4787 val_dice=0.8948 val_iou=0.8137 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 1/3] Epoch
lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 3/3] Epoch 177/250 - train_loss=0.0611 val_loss=0.1194 val_dice=0.9151 val_iou=0.8451 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 3/3] Epoch 178/250 - train_loss=0.0594 val_loss=0.1161 val_dice=0.9179 val_iou=0.8498 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 3/3] Epoch 179/250 - train_loss=0.0578 val_loss=0.1089 val_dice=0.9186 val_iou=0.8508 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 3/3] Epoch 180/250 - train_loss=0.0577 val_loss=0.1069 val_dice=0.9195 val_iou=0.8522 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 3/3] Epoch 181/250 - train_loss=0.0568 val_loss=0.1246 val_dice=0.9181 val_iou=0.8499 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 3/3] Epoch 182/250 - train_loss=0.0570 val_loss=0.1057 val_dice=0.9190 val_iou=0.8513 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 3/3] Epoch 183/250 - train_loss=0.0563 val_loss=0.1002 val_dice=0.9173 val_iou=0.8483 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 3/3] Epoch 184/250 - train_loss=0.0548 val_loss=0.1207 val_dice=0.9148 val_iou=0.8446 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 3/3] Epoch 185/250 - train_loss=0.0546 val_loss=0.1008 val_dice=0.9139 val_iou=0.8428 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 3/3] Epoch 186/250 - train_loss=0.0568 val_loss=0.1012 val_dice=0.9151 val_iou=0.8452 lr=5.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 3/3] Epoch 187/250 - train_loss=0.0557 val_loss=0.1288 val_dice=0.9098 val_iou=0.8363 lr=2.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 3/3] Epoch 188/250 - train_loss=0.0564 val_loss=0.1107 val_dice=0.9190 val_iou=0.8513 lr=2.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 3/3] Epoch 189/250 - train_loss=0.0529 val_loss=0.1114 val_dice=0.9188 val_iou=0.8510 lr=2.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 3/3] Epoch 190/250 - train_loss=0.0534 val_loss=0.1160 val_dice=0.9175 val_iou=0.8488 lr=2.99e-04
# [hybrid_strong_transunet_forniceal_palpebral | fold 3] Early stopping at epoch 190 (no val_loss improvement for 7 epochs).
# --- Fold 3 test-set evaluation (best_hybrid_strong_transunet_forniceal_palpebral_fold3.pth) ---
# Fold 3 test Dice=0.9241 IoU=0.8604 HD95=10.11px
#
# --- Measuring architecture properties (params, inference latency) ---
# Parameters: 120,876,817
# Inference latency (batch_size=1, 256x256): 17.76 ms
#
# Saved per-fold summary to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/hybrid_strong_transunet_forniceal_palpebral_kfold_folds.csv
#
# --- Aggregate across folds (mean +/- std) ---
#   dice       = 0.9268 +/- 0.0023
#   iou        = 0.8654 +/- 0.0043
#   precision  = 0.9271 +/- 0.0049
#   recall     = 0.9308 +/- 0.0019
#   hd95       = 10.3590 +/- 1.0308
# Saved per-patient-per-fold test metrics to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/hybrid_strong_transunet_forniceal_palpebral_kfold_test_per_patient.csv
# Saved K-fold summary to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/logs/hybrid_strong_transunet_forniceal_palpebral_kfold_summary.json
# Saved 5 plots to /kaggle/working/eyes-defy-anemia/Segmentation/outputs/plots:
#   hybrid_strong_transunet_forniceal_palpebral_kfold_mean_curve.png
#   hybrid_strong_transunet_forniceal_palpebral_fold_dice_distribution.png
#   hybrid_strong_transunet_forniceal_palpebral_test_summary.png
#   hybrid_strong_transunet_forniceal_palpebral_test_by_country.png
#   hybrid_strong_transunet_forniceal_palpebral_test_per_patient_dice.png
# [sync_outputs] 22 files consolidated under /kaggle/working/outputs, zipped to /kaggle/working/segmentation_sweep_results.zip

# %% [markdown]
# ## Done — what to download
#
# This tier's fold checkpoints (fp16), logs (`*_kfold_summary.json`, `*_kfold_folds.csv`, `*_kfold_test_per_patient.csv`), and plots are consolidated at `/kaggle/working/outputs/` and zipped to `/kaggle/working/segmentation_sweep_results.zip`, visible in this notebook version's **Output** tab once you Save Version -> Save & Run All — download the zip directly from there.
#
# A failed `!python ...` cell does **not** halt "Run All" — check each script's own printed output (or the saved `*_kfold_summary.json` files) after this finishes.

# %%
from pathlib import Path

print('Final contents of /kaggle/working/outputs:')
for f in sorted(Path('/kaggle/working/outputs').rglob('*')):
    if f.is_file():
        print(f'  {f.relative_to("/kaggle/working/outputs")}  ({f.stat().st_size / 1e6:.2f} MB)')

zip_path = Path('/kaggle/working/segmentation_sweep_results.zip')
print(f"\nZip archive: {zip_path}  ({zip_path.stat().st_size / 1e6:.2f} MB)")
# Out:
# Final contents of /kaggle/working/outputs:
#   checkpoints/best_hybrid_strong_transunet_forniceal_palpebral_fold1.pth  (242.06 MB)
#   checkpoints/best_hybrid_strong_transunet_forniceal_palpebral_fold2.pth  (242.06 MB)
#   checkpoints/best_hybrid_strong_transunet_forniceal_palpebral_fold3.pth  (242.06 MB)
#   checkpoints/best_hybrid_strong_transunet_palpebral_fold1.pth  (242.05 MB)
#   checkpoints/best_hybrid_strong_transunet_palpebral_fold2.pth  (242.05 MB)
#   checkpoints/best_hybrid_strong_transunet_palpebral_fold3.pth  (242.05 MB)
#   logs/hybrid_strong_transunet_forniceal_palpebral_kfold_folds.csv  (0.00 MB)
#   logs/hybrid_strong_transunet_forniceal_palpebral_kfold_summary.json  (0.00 MB)
#   logs/hybrid_strong_transunet_forniceal_palpebral_kfold_test_per_patient.csv  (0.01 MB)
#   logs/hybrid_strong_transunet_palpebral_kfold_folds.csv  (0.00 MB)
#   logs/hybrid_strong_transunet_palpebral_kfold_summary.json  (0.00 MB)
#   logs/hybrid_strong_transunet_palpebral_kfold_test_per_patient.csv  (0.01 MB)
#   plots/hybrid_strong_transunet_forniceal_palpebral_fold_dice_distribution.png  (0.03 MB)
#   plots/hybrid_strong_transunet_forniceal_palpebral_kfold_mean_curve.png  (0.14 MB)
#   plots/hybrid_strong_transunet_forniceal_palpebral_test_by_country.png  (0.04 MB)
#   plots/hybrid_strong_transunet_forniceal_palpebral_test_per_patient_dice.png  (0.04 MB)
#   plots/hybrid_strong_transunet_forniceal_palpebral_test_summary.png  (0.04 MB)
#   plots/hybrid_strong_transunet_palpebral_fold_dice_distribution.png  (0.03 MB)
#   plots/hybrid_strong_transunet_palpebral_kfold_mean_curve.png  (0.19 MB)
#   plots/hybrid_strong_transunet_palpebral_test_by_country.png  (0.04 MB)
#   plots/hybrid_strong_transunet_palpebral_test_per_patient_dice.png  (0.04 MB)
#   plots/hybrid_strong_transunet_palpebral_test_summary.png  (0.04 MB)
#
# Zip archive: /kaggle/working/segmentation_sweep_results.zip  (1338.47 MB)
